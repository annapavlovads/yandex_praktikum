# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Условия-задачи,-техническая-справка-и-план-исследования" data-toc-modified-id="Условия-задачи,-техническая-справка-и-план-исследования-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Условия задачи, техническая справка и план исследования</a></span><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#План-исследования" data-toc-modified-id="План-исследования-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>План исследования</a></span></li><li><span><a href="#Технические-факты-и-описание-этапа-обработки" data-toc-modified-id="Технические-факты-и-описание-этапа-обработки-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Технические факты и описание этапа обработки</a></span></li><li><span><a href="#Используемые-библиотеки" data-toc-modified-id="Используемые-библиотеки-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Используемые библиотеки</a></span></li><li><span><a href="#Используемые-функции" data-toc-modified-id="Используемые-функции-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Используемые функции</a></span></li></ul></li><li><span><a href="#Загрузка,-изучение-и-первичная-обработка-данных" data-toc-modified-id="Загрузка,-изучение-и-первичная-обработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузка, изучение и первичная обработка данных</a></span><ul class="toc-item"><li><span><a href="#Данные-об-электродах" data-toc-modified-id="Данные-об-электродах-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Данные об электродах</a></span></li><li><span><a href="#Данные-о-подаче-сыпучих-материалов-(объём)" data-toc-modified-id="Данные-о-подаче-сыпучих-материалов-(объём)-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Данные о подаче сыпучих материалов (объём)</a></span></li><li><span><a href="#Данные-о-подаче-сыпучих-материалов-(время)" data-toc-modified-id="Данные-о-подаче-сыпучих-материалов-(время)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Данные о подаче сыпучих материалов (время)</a></span></li><li><span><a href="#Данные-о-продувке-сплава-газом" data-toc-modified-id="Данные-о-продувке-сплава-газом-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Данные о продувке сплава газом</a></span></li><li><span><a href="#Результаты-измерения-температуры" data-toc-modified-id="Результаты-измерения-температуры-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Результаты измерения температуры</a></span></li><li><span><a href="#Данные-о-проволочных-материалах-(объём)" data-toc-modified-id="Данные-о-проволочных-материалах-(объём)-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Данные о проволочных материалах (объём)</a></span></li><li><span><a href="#Данные-о-проволочных-материалах-(время)" data-toc-modified-id="Данные-о-проволочных-материалах-(время)-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Данные о проволочных материалах (время)</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Формат-даты/времени" data-toc-modified-id="Формат-даты/времени-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Формат даты/времени</a></span></li><li><span><a href="#Добавление-данных-в-датасет-об-электродах" data-toc-modified-id="Добавление-данных-в-датасет-об-электродах-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Добавление данных в датасет об электродах</a></span></li><li><span><a href="#Данные-о-температуре---выделение-целевого-признака" data-toc-modified-id="Данные-о-температуре---выделение-целевого-признака-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Данные о температуре - выделение целевого признака</a></span></li><li><span><a href="#Данные-о-температуре---добавление-features" data-toc-modified-id="Данные-о-температуре---добавление-features-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Данные о температуре - добавление features</a></span></li><li><span><a href="#Данные-о-работе-электродов---добавление-features" data-toc-modified-id="Данные-о-работе-электродов---добавление-features-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Данные о работе электродов - добавление features</a></span></li><li><span><a href="#Данные-о-проволочных-материалах---добавление-features" data-toc-modified-id="Данные-о-проволочных-материалах---добавление-features-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Данные о проволочных материалах - добавление features</a></span></li><li><span><a href="#Данные-о-подаче-сыпучих-материалов-(шлака)---добавление-features" data-toc-modified-id="Данные-о-подаче-сыпучих-материалов-(шлака)---добавление-features-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Данные о подаче сыпучих материалов (шлака) - добавление features</a></span></li><li><span><a href="#Объединение-таблиц" data-toc-modified-id="Объединение-таблиц-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Объединение таблиц</a></span></li><li><span><a href="#Исследовательский-анализ-сборного-датасета" data-toc-modified-id="Исследовательский-анализ-сборного-датасета-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Исследовательский анализ сборного датасета</a></span></li><li><span><a href="#Поиск-выбросов-по-совокупности-feature" data-toc-modified-id="Поиск-выбросов-по-совокупности-feature-3.10"><span class="toc-item-num">3.10&nbsp;&nbsp;</span>Поиск выбросов по совокупности feature</a></span></li></ul></li><li><span><a href="#Подготовка-признаков-для-моделей" data-toc-modified-id="Подготовка-признаков-для-моделей-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Подготовка признаков для моделей</a></span><ul class="toc-item"><li><span><a href="#Разделение-на-обучающую-и-тестовую-выборки" data-toc-modified-id="Разделение-на-обучающую-и-тестовую-выборки-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Разделение на обучающую и тестовую выборки</a></span></li><li><span><a href="#Dummy-модель" data-toc-modified-id="Dummy-модель-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Dummy модель</a></span></li></ul></li><li><span><a href="#Выбор-и-обучение-моделей" data-toc-modified-id="Выбор-и-обучение-моделей-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Выбор и обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Linear-Regression" data-toc-modified-id="Linear-Regression-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Linear Regression</a></span></li><li><span><a href="#Random-Forest-Regressor" data-toc-modified-id="Random-Forest-Regressor-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Random Forest Regressor</a></span></li><li><span><a href="#Gradient-Boosting-Regregressor" data-toc-modified-id="Gradient-Boosting-Regregressor-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Gradient Boosting Regregressor</a></span></li><li><span><a href="#Cat-Boost-Regressor" data-toc-modified-id="Cat-Boost-Regressor-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Cat Boost Regressor</a></span></li></ul></li><li><span><a href="#Тестирование-моделей" data-toc-modified-id="Тестирование-моделей-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Тестирование моделей</a></span><ul class="toc-item"><li><span><a href="#Linear-Regression" data-toc-modified-id="Linear-Regression-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Linear Regression</a></span></li><li><span><a href="#Random-Forest-Regressor" data-toc-modified-id="Random-Forest-Regressor-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Random Forest Regressor</a></span></li><li><span><a href="#Gradient-Boosting-Regregressor" data-toc-modified-id="Gradient-Boosting-Regregressor-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Gradient Boosting Regregressor</a></span></li><li><span><a href="#Cat-Boost-Regressor" data-toc-modified-id="Cat-Boost-Regressor-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Cat Boost Regressor</a></span></li><li><span><a href="#Сравнение-моделей" data-toc-modified-id="Сравнение-моделей-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Сравнение моделей</a></span></li><li><span><a href="#Время-предсказания-на-тестовой-выборке:" data-toc-modified-id="Время-предсказания-на-тестовой-выборке:-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Время предсказания на тестовой выборке:</a></span></li></ul></li></ul></div>

# %% [markdown]
# <hr>

# %% [markdown]
# # Прогнозирование температуры плавления стали

# %% [markdown]
# <hr>

# %% [markdown]
# ## Условия задачи, техническая справка и план исследования

# %% [markdown]
# __Условие задачи__

# %% [markdown]
# Чтобы оптимизировать производственные расходы, металлургический комбинат ООО «Так закаляем сталь» решил уменьшить потребление электроэнергии на этапе обработки стали. Вам предстоит построить модель, которая предскажет температуру стали.

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Данные состоят из файлов, полученных из разных источников:
# - data_arc.csv — данные об электродах;
# - data_bulk.csv — данные о подаче сыпучих материалов (объём);
# - data_bulk_time.csv — данные о подаче сыпучих материалов (время);
# - data_gas.csv — данные о продувке сплава газом;
# - data_temp.csv — результаты измерения температуры;
# - data_wire.csv — данные о проволочных материалах (объём);
# - data_wire_time.csv — данные о проволочных материалах (время).

# %% [markdown]
# Во всех файлах столбец key содержит номер партии. <div>
# В файлах может быть несколько строк с одинаковым значением key: они соответствуют разным итерациям обработки.

# %% [markdown]
# ### План исследования

# %% [markdown]
# - Загрузить и рассмотреть данные в первом приближении.
# - Подготовить данные. Изменить типы данных; определить и использовать номера партий, у которых есть замеры по температуре.
# - Подготовка признаков. Составление единой таблицы со всеми данными для модели. Выделение целевого признака как последний замер в серии замеров. Разделение на features и target.
# - Выбор моделей. Использование и обучение регрессионных моделей.
# - Оценка эффективности моделей на тестовой выборке.
# - Сделать выводы.

# %% [markdown]
# ### Технические факты и описание этапа обработки

# %% [markdown]
# - Сталь обрабатывают в металлическом ковше вместимостью около 100 тонн. Чтобы ковш выдерживал высокие температуры, изнутри его облицовывают огнеупорным кирпичом. Расплавленную сталь заливают в ковш и подогревают до нужной температуры графитовыми электродами. Они установлены в крышке ковша.
#
# - Из сплава выводится сера (десульфурация), добавлением примесей корректируется химический состав и отбираются пробы. Сталь легируют — изменяют её состав — подавая куски сплава из бункера для сыпучих материалов или проволоку через специальный трайб-аппарат (англ. tribe, «масса»).
#
# - Перед тем как первый раз ввести легирующие добавки, измеряют температуру стали и производят её химический анализ. Потом температуру на несколько минут повышают, добавляют легирующие материалы и продувают сплав инертным газом. Затем его перемешивают и снова проводят измерения. Такой цикл повторяется до достижения целевого химического состава и оптимальной температуры плавки.
#
# - Тогда расплавленная сталь отправляется на доводку металла или поступает в машину непрерывной разливки. Оттуда готовый продукт выходит в виде заготовок-слябов (англ. slab, «плита»).

# %% [markdown]
# Факты:
# - Технология пришла из Японии;
# - Цель процесса: рафинирование и достижение необходимых свойств металла;
# - Наличие ковшей позволяет понизить температуру процесса. Улучшается производительность печей для плавления стали, дольше работает сама установка;
# - Ковш вмещает от 30 до 150 т металла;
# - Температура металла повышается обычно на 5°С в минуту;
# - Оптимальная температура, которую необходимо поддерживать в тигель-ковше, равняется примерно 1600°С;
# - Общее время процесса составляет 60-90 минут. Дуговой нагрев происходит циклически, от 10 до 30 минут;
# - Когда рафинирующие операции завершены, металл выливается из тигель-ковша с помощью шиберного затвора. Сталь попадает в сталеразливочный ковш, далее поступает на разливку в формы или на МНЛЗ.

# %% [markdown]
# Пути снижения энергозатрат:
# - Рациональное применение высокой температуры отработанного шлака – для нагрева ковшей, шлакообразующей шихты и других элементов;
# - Применение порошкообразных материалов в процессе продувки аргоном сквозь другую фурму – способствует избавлению от серы и повышает скорость раскисления металла. Уменьшается длительность процесса – снижаются затраты энергии;
# - Усиленное смешивание шлака со сталью при помощи перемешивающего индуктора – также сокращает длительность обработки.

# %% [markdown]
# ![jupyter](https://metallplace.ru/upload/metphoto/kovshpech.jpg)

# %% [markdown]
# Источник: https://metallplace.ru

# %% [markdown]
# ### Используемые библиотеки

# %%
# basic
import pandas as pd
import numpy as np

# date and time 
import datetime 
from datetime import datetime, date

# data viz
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas.plotting import scatter_matrix
import seaborn as sns
sns.set(style='whitegrid')

# time 
import time

# basic instruments
import random
import math

# statisctics 
# import statsmodels.api as sm
# from scipy import stats
# from scipy.stats import boxcox

# best parameters search
# import optuna
# from sklearn.model_selection import GridSearchCV 
# from sklearn.model_selection import KFold, StratifiedKFold
# from sklearn.feature_selection import RFE
# from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_validate, cross_val_score, GridSearchCV

# #machine learning models
from sklearn.ensemble import IsolationForest
from sklearn.dummy import DummyRegressor
# from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LinearRegression  
# from sklearn.linear_model import Lasso
# from sklearn.linear_model import Ridge
#from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
#from sklearn.neural_network import MLPRegressor 
from lightgbm import LGBMRegressor
from sklearn.ensemble import GradientBoostingRegressor
from catboost import CatBoostRegressor

# #dummy
# from sklearn.dummy import DummyRegressor
# from sklearn.dummy import DummyClassifier

# import xgboost
# import catboost
# from catboost import Pool, CatBoostRegressor, cv

# ML instruments
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

# encoders
# from sklearn.preprocessing import OrdinalEncoder
# from sklearn.preprocessing import OneHotEncoder
# from sklearn.preprocessing import Normalizer
# from sklearn.preprocessing import Binarizer
# #import category_encoders as ce

# sklearn instruments
from sklearn.utils import shuffle
from sklearn.pipeline import Pipeline

# feature engineering
# from pandas.api.types import is_categorical_dtype
# from sklearn.cluster import KMeans
# from sklearn.decomposition import PCA

# metrics
from sklearn.metrics import mean_squared_error
# from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
# from sklearn.metrics import roc_auc_score, precision_recall_curve, roc_curve
from sklearn.model_selection import cross_val_score
# from sklearn.metrics import plot_precision_recall_curve
# from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, make_scorer


#dataset settings
pd.set_option('display.max_columns', 40) #макс кол-во колонок в выводимых данных 
pd.set_option('display.max_rows', 20) #макс кол-во строк в выводимых данных
pd.set_option('display.width', 20) #макс кол-во символов в строке

#warnings and other settings
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.simplefilter('ignore')
pd.options.mode.chained_assignment = None

#random state
rs=116

# %% [markdown]
# ### Используемые функции

# %% [markdown]
# Функция с общей информацией о датасете:

# %%
def df_info(df):
    display(df.shape)
    display(df.head(5))
    display(df.info())
    display(df.describe())
    print('Дубликаты')
    print(df[df.duplicated(keep="first")].count())
    print()
    print('Пропуски')
    for col in df.columns:
        pct_missing = np.mean(df[col].isnull())
        print('{} - {}%'.format(col, round(pct_missing*100), sep=''))

# %% [markdown]
# Функция для преобразования даты:

# %%
def datetime(df, column):
    df[column] = pd.to_datetime(df[column], format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# Функция для матрицы корреляций:

# %%
def num_corr(df, cols=None, hue=None):
    if cols == None:
        cols = [col for col in df.columns if df[col].dtype in ['float64','int64']]
    
    corr = round(df[cols].corr(), 2)
    #display(corr)
    
    mask = np.zeros_like(corr)
    mask[np.triu_indices_from(mask)] = True
    f, ax = plt.subplots(figsize=(40, 20))
    ax = sns.heatmap(corr, mask=mask, center=0, vmax=1, vmin=-1, square=True, annot=True, cmap='YlGnBu')
    plt.show()
    
    sns.pairplot(data=df, x_vars=cols, y_vars=cols, corner=True, diag_kind='kde', hue=hue)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Функция подбора гиперпараметров:

# %%
def grid_search(model, params, feat, targ):
      
    search = GridSearchCV(model, params, cv=5, scoring='neg_mean_absolute_error', n_jobs=-1, verbose=1)
    search.fit(feat, targ)
    
    print(search.best_score_)
    print(search.best_params_)

# %% [markdown]
# Кросс-валидация:

# %%
def cv_score(model, feat, targ):
    
    score = cross_val_score(model, feat, targ, cv=5, scoring='neg_mean_absolute_error')
    
    print('Результат кросс валидации', score)
    print('Результат средний', score.mean().round(3))

# %% [markdown]
# Предсказания на train и test и подсчет MAE:

# %%
def prediction_train(model, train_feat, train_targ): 
    
    mae_train = mean_absolute_error(train_targ, model.predict(train_feat)) 
    print('MAE на обучающей выборке', mae_train.round(3))
    
def prediction_test(model, test_feat, test_targ):
    
    mae_test = mean_absolute_error(test_targ, model.predict(test_feat))
    model_mae = mae_test.round(3)
    print('MAE на тестовой выборке', model_mae)
    
def train_mae(model): 
    return mean_absolute_error(target_train, model.predict(features_train))

def test_mae(model): 
    return mean_absolute_error(target_test, model.predict(features_test))

# %% [markdown]
# Таблица и функция обновления таблицы с итоговыми данными моделей:

# %%
result_data = pd.DataFrame(columns=['model','time_learn, ms','time_predict, ms','mae_train','mae_test'])
result_data
# Out:
# Empty DataFrame
# Columns: [model, time_learn, ms, time_predict, ms, mae_train, mae_test]
# Index: []

# %%
def results_upd_train(row, model, time_learn, mae_train):
    
    result_data.loc[row, 'model'] = model
    result_data.loc[row, 'time_learn, ms'] = time_learn
    result_data.loc[row, 'mae_train'] = mae_train
    
    display(result_data)
    
def results_upd_test(row, time_pred, mae_test):
    
    result_data.loc[row, 'time_predict, ms'] = time_pred
    result_data.loc[row, 'mae_test'] = mae_test
    
    display(result_data)

# %% [markdown]
# Функция для подсвечивания модели, достигшей нужной метрики:

# %%
def highlight_background(s):
    return ['background-color: green' if v <= 6.0 else 'background-color: goldenrod' for v in s]

def color_text(val):
    color = 'black' if val == 'yes' else 'white'
    return 'color: %s' % color

# %% [markdown]
# ## Загрузка, изучение и первичная обработка данных

# %% [markdown]
# ### Данные об электродах

# %% [markdown]
# __data_arc.csv__ — данные об электродах

# %%
try: 
    data_arc = pd.read_csv('/datasets/data_arc.csv')
    
except: 
    data_arc = pd.read_csv('datasets/data_arc.csv')
    
df_info(data_arc)
# Out:
# (14876, 5)
#    key  \
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
#
#   Начало нагрева дугой  \
# 0  2019-05-03 11:02:14
# 1  2019-05-03 11:07:28
# 2  2019-05-03 11:11:44
# 3  2019-05-03 11:18:14
# 4  2019-05-03 11:26:09
#
#    Конец нагрева дугой  \
# 0  2019-05-03 11:06:02
# 1  2019-05-03 11:10:33
# 2  2019-05-03 11:14:36
# 3  2019-05-03 11:24:19
# 4  2019-05-03 11:28:37
#
#    Активная мощность  \
# 0           0.976059
# 1           0.805607
# 2           0.744363
# 3           1.659363
# 4           0.692755
#
#    Реактивная мощность
# 0             0.687084
# 1             0.520285
# 2             0.498805
# 3             1.062669
# 4             0.414397
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14876 entries, 0 to 14875
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   key                   14876 non-null  int64
#  1   Начало нагрева дугой  14876 non-null  object
# ...

# %% [markdown]
# Даты требуют приведения к формату даты, пропусков и дубликатов не обнаружено.

# %%
datetime(data_arc, 'Начало нагрева дугой')
datetime(data_arc, 'Конец нагрева дугой')

# %%
print(data_arc['Начало нагрева дугой'].min(), data_arc['Начало нагрева дугой'].max())
print(data_arc['Конец нагрева дугой'].min(), data_arc['Конец нагрева дугой'].max())
# Out:
# 2019-05-03 11:02:14 2019-09-01 04:34:47
# 2019-05-03 11:06:02 2019-09-01 04:36:08

# %%
print((data_arc['Конец нагрева дугой'] - data_arc['Начало нагрева дугой']).median())
# Out:
# 0 days 00:02:27

# %%
len(data_arc['key'].unique())
# Out:
# 3214

# %% [markdown]
# В данных видим:

# %% [markdown]
# - 14876 строк, 5 столбцов.
# - Данные содержат описание работы электродов, с 3 мая по 1 сентября 2019.
# - Обработано 3214 партий металла.
# - Один цикл работы электродов длится, в среднем 2,5 минуты.

# %% [markdown]
# __Построим ящики с усами для активной и реактивной мощности__

# %%
plt.figure(figsize=(5,9))
plt.boxplot(data_arc['Активная мощность'])
#plt.title()
plt.xlabel('Активная мощность')
#plt.ylabel()
plt.xticks()
plt.show()

# %%
plt.figure(figsize=(5,9))
plt.boxplot(data_arc['Реактивная мощность'])
#plt.title()
plt.xlabel('Реактивная мощность')
#plt.ylabel()
plt.xticks()
plt.show()

# %% [markdown]
# В случае с реактивной мощностью видим один очень сильный выброс, который превращает весь ящик в ничто. Исследуем и удалим его.

# %%
data_arc.drop(index=data_arc.loc[data_arc['Реактивная мощность']==data_arc['Реактивная мощность'].min()].index, inplace=True)

# %%
plt.figure(figsize=(5,9))
plt.boxplot(data_arc['Реактивная мощность'])
#plt.title()
plt.xlabel('Реактивная мощность')
#plt.ylabel()
plt.xticks()
plt.show()

# %%
data_arc['Реактивная мощность'].describe()
# Out:
# count    14875.000000
# mean         0.500723
# std          0.310880
# min          0.020806
# 25%          0.291003
# 50%          0.415984
# 75%          0.637403
# max          2.676388
# Name: Реактивная мощность, dtype: float64

# %% [markdown]
# Теперь видим, что мощность осталась только больше нуля, что так и должно быть.

# %% [markdown]
# Вообще, в каждом boxplot мы видим и другие выбросы. Пока будем их удалять, посмотрим как покажут себя модели.

# %% [markdown]
# __Распределение данных__

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.distplot(data_arc['Активная мощность'], color='dimgrey')
plt.xlabel('Активная мощность', size=12)
plt.ylabel('Плотность вероятности', size=12)
plt.title('Распределение значений активной мощности', size=16);

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.distplot(data_arc['Реактивная мощность'], color='dimgrey')
plt.xlabel('Реактивная мощность', size=12)
plt.ylabel('Плотность вероятности', size=12)
plt.title('Распределение значений реактивной мощности', size=16);

# %% [markdown]
# Распределение активной и реактивной мощности имеют длинные хвосты справа. Необходимо уточнить у технических специалистов, имеет ли это влияние на технологический процесс, и если да, то какое.

# %% [markdown]
# ### Данные о подаче сыпучих материалов (объём)

# %% [markdown]
# __data_bulk.csv__ — данные о подаче сыпучих материалов (объём)

# %%
try: 
    data_bulk = pd.read_csv('/datasets/data_bulk.csv')
    
except: 
    data_bulk = pd.read_csv('datasets/data_bulk.csv')
    
df_info(data_bulk)
# Out:
# (3129, 16)
#    key  Bulk 1  \
# 0    1     NaN
# 1    2     NaN
# 2    3     NaN
# 3    4     NaN
# 4    5     NaN
#
#    Bulk 2  Bulk 3  \
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
#
#    Bulk 4  Bulk 5  \
# 0    43.0     NaN
# 1    73.0     NaN
# 2    34.0     NaN
# 3    81.0     NaN
# 4    78.0     NaN
#
#    Bulk 6  Bulk 7  \
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
#
#    Bulk 8  Bulk 9  \
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
#
#    Bulk 10  \
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
#    Bulk 11  \
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
#    Bulk 12  \
# 0    206.0
# 1    206.0
# 2    205.0
# 3    207.0
# 4    203.0
#
#    Bulk 13  \
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
#    Bulk 14  \
# 0    150.0
# 1    149.0
# ...

# %%
data_bulk['key'].nunique()
# Out:
# 3129

# %% [markdown]
# <div class="alert alert-danger">
# <b>ВОПРОС К КОЛИЧЕСТВУ УНИКАЛЬНЫХ keys</b> </div>

# %% [markdown]
# __data_bulk_time.csv__ — данные о подаче сыпучих материалов (время)

# %%
try: 
    data_bulk_time = pd.read_csv('/datasets/data_bulk_time.csv')
    
except: 
    data_bulk_time = pd.read_csv('datasets/data_bulk_time.csv')
    
df_info(data_bulk_time)
# Out:
# (3129, 16)
#    key Bulk 1  \
# 0    1    NaN
# 1    2    NaN
# 2    3    NaN
# 3    4    NaN
# 4    5    NaN
#
#   Bulk 2 Bulk 3  \
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN
#
#                 Bulk 4  \
# 0  2019-05-03 11:21:30
# 1  2019-05-03 11:46:38
# 2  2019-05-03 12:31:06
# 3  2019-05-03 12:48:43
# 4  2019-05-03 13:18:50
#
#   Bulk 5 Bulk 6  \
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN
#
#   Bulk 7 Bulk 8  \
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN
#
#   Bulk 9 Bulk 10  \
# 0    NaN     NaN
# 1    NaN     NaN
# 2    NaN     NaN
# 3    NaN     NaN
# 4    NaN     NaN
#
#   Bulk 11  \
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#
#                Bulk 12  \
# 0  2019-05-03 11:03:52
# 1  2019-05-03 11:40:20
# 2  2019-05-03 12:09:40
# 3  2019-05-03 12:41:24
# 4  2019-05-03 13:12:56
#
#   Bulk 13  \
# 0     NaN
# 1     NaN
# ...

# %% [markdown]
# __Выводы:__

# %% [markdown]
# - 15 столбцов - 15 различных добавок
# - больше всего добавляют сыпучих материалов под номерами: 15, 14, 12, 3, 4
# - меньше всего добавок под номерами 2, 7 и 8.

# %% [markdown]
# __Распределение значений добавления сыпучих присадок в ковш-печь__

# %%
fig, axes = plt.subplots(15,1, figsize=(8,38))

for i, j in zip(data_bulk.columns[1:], 
                range(data_bulk.shape[1]+1)):
                    sns.boxplot(data_bulk[i], color='dimgray', ax=axes[j])
                    axes[j].set_title(i, x=0.95, y=0.7, size=12)

axes[14].set_xlabel('', size=8)

plt.suptitle('Распределение значений добавления сыпучих присадок в ковш-печь', size=18, y=0.895);

# %% [markdown]
# В каждой порции есть один большой выброс справа. Посмотрим, не в одном ли key это произошло.

# %%
my_list=[]
for column in data_bulk.columns: 
    my_list.append(data_bulk[column].sort_values(ascending=False).head(1).index)
pd.DataFrame(my_list).value_counts()
# Out:
# 303     3
# 1725    2
# 104     1
# 560     1
# 639     1
# 961     1
# 983     1
# 1219    1
# 1629    1
# 1747    1
# 2032    1
# 2055    1
# 3128    1
# dtype: int64

# %% [markdown]
# Видим, что в key 303 и 1725 это случилось дважды, в остальных партиях единожды. Возможно, это особенность технологического процесса. <div> Пока не будем удалять их, посмотрим, как они коррелируют с температурой.

# %% [markdown]
# ### Данные о подаче сыпучих материалов (время)

# %%
try: 
    data_bulk_time = pd.read_csv('/datasets/data_bulk_time.csv')
    
except: 
    data_bulk_time = pd.read_csv('datasets/data_bulk_time.csv')
    
df_info(data_bulk_time)
# Out:
# (3129, 16)
#    key Bulk 1  \
# 0    1    NaN
# 1    2    NaN
# 2    3    NaN
# 3    4    NaN
# 4    5    NaN
#
#   Bulk 2 Bulk 3  \
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN
#
#                 Bulk 4  \
# 0  2019-05-03 11:21:30
# 1  2019-05-03 11:46:38
# 2  2019-05-03 12:31:06
# 3  2019-05-03 12:48:43
# 4  2019-05-03 13:18:50
#
#   Bulk 5 Bulk 6  \
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN
#
#   Bulk 7 Bulk 8  \
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN
#
#   Bulk 9 Bulk 10  \
# 0    NaN     NaN
# 1    NaN     NaN
# 2    NaN     NaN
# 3    NaN     NaN
# 4    NaN     NaN
#
#   Bulk 11  \
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#
#                Bulk 12  \
# 0  2019-05-03 11:03:52
# 1  2019-05-03 11:40:20
# 2  2019-05-03 12:09:40
# 3  2019-05-03 12:41:24
# 4  2019-05-03 13:12:56
#
#   Bulk 13  \
# 0     NaN
# 1     NaN
# ...

# %% [markdown]
# Это данные о времени ввода сыпучих веществ в ковш. Пропуски означает, что не добавляли ничего и соответствует пропускам в данным из предыдущего датасета data_bulk. Возможны добавки порций различных видов вещества одновременно.

# %% [markdown]
# ### Данные о продувке сплава газом

# %% [markdown]
# __data_gas.csv__ — данные о продувке сплава газом

# %%
try: 
    data_gas = pd.read_csv('/datasets/data_gas.csv')
    
except: 
    data_gas = pd.read_csv('datasets/data_gas.csv')
    
df_info(data_gas)
# Out:
# (3239, 2)
#    key      Газ 1
# 0    1  29.749986
# 1    2  12.555561
# 2    3  28.554793
# 3    4  18.841219
# 4    5   5.413692
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3239 entries, 0 to 3238
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3239 non-null   int64
#  1   Газ 1   3239 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 50.7 KB
# None
#                key  \
# count  3239.000000
# mean   1621.861377
# std     935.386334
# min       1.000000
# 25%     812.500000
# 50%    1622.000000
# 75%    2431.500000
# max    3241.000000
#
#              Газ 1
# count  3239.000000
# mean     11.002062
# std       6.220327
# min       0.008399
# 25%       7.043089
# 50%       9.836267
# 75%      13.769915
# max      77.995040
# Дубликаты
# key      0
# Газ 1    0
# dtype: int64
#
# Пропуски
# key - 0%
# Газ 1 - 0%

# %% [markdown]
# <div class="alert alert-danger">
# <b>ВОПРОС К КОЛИЧЕСТВУ УНИКАЛЬНЫХ keys</b> </div>

# %%
len(data_gas['key'].unique())
# Out:
# 3239

# %% [markdown]
# Посмотрим на распределение данных:

# %%
plt.figure(figsize=(8,4))
sns.distplot(data_gas['Газ 1'], rug=True, color='dimgray')
plt.xlabel('')
plt.ylabel('Плотность вероятности')
plt.title('Распределение значений добавления инертного газа', size=18, y=1.01);

# %% [markdown]
# Есть некоторое количество выбивающихся значений. <div>
#     Необходимо уточнить у технических специалистов, это некорректные данные / некорректное поведение в рамках технологического процесса / особенность технологического процесса.

# %% [markdown]
# ### Результаты измерения температуры

# %% [markdown]
# __data_temp.csv__ — результаты измерения температуры

# %% [markdown]
# Из этого датасета мы достанем начальную температуру, как признак (feature), а также финальную температуру, как целевой признак (target) - на этапе предобработки данных для моделей.

# %%
try: 
    data_temp = pd.read_csv('/datasets/data_temp.csv')
    
except: 
    data_temp = pd.read_csv('datasets/data_temp.csv')
    
df_info(data_temp)
# Out:
# (15907, 3)
#    key  \
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
#
#           Время замера  \
# 0  2019-05-03 11:16:18
# 1  2019-05-03 11:25:53
# 2  2019-05-03 11:29:11
# 3  2019-05-03 11:30:01
# 4  2019-05-03 11:30:39
#
#    Температура
# 0       1571.0
# 1       1604.0
# 2       1618.0
# 3       1601.0
# 4       1613.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15907 entries, 0 to 15906
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   key           15907 non-null  int64
#  1   Время замера  15907 non-null  object
#  2   Температура   13006 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 372.9+ KB
# None
#                 key  \
# count  15907.000000
# mean    1607.880870
# std      942.212073
# min        1.000000
# 25%      790.000000
# 50%     1618.000000
# 75%     2427.000000
# max     3241.000000
#
#         Температура
# count  13006.000000
# ...

# %% [markdown]
# Есть пропуски в замерах температуры

# %%
data_temp['key'].nunique()
# Out:
# 3216

# %% [markdown]
# __Распределение температуры__

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.distplot(data_temp['Температура'], color='dimgrey')
plt.xlabel('Температура', size=12)
plt.ylabel('Плотность вероятности', size=12)
plt.title('Распределение Температура', size=16);

# %% [markdown]
# Как и сказано в описании технологического процесса, основная рабочая температура - около 1600 градусов, при этом есть незначительный хвост в меньшую сторону. Вот он:

# %%
plt.figure(figsize=(8,4))

sns.boxplot(data_temp['Температура'], color='dimgray')

plt.xlabel('Температура, *С', size=14)
plt.title('Распределение температуры внутри ковша', size=18, y=1.02);

# %% [markdown]
# В температуре есть выбросы в сторону более низких значений, чем основные, и те, что указаны в качестве основных по технологическому процессу.

# %%
data_temp.loc[data_temp['Температура'] <= 1500].shape[0]
# Out:
# 7

# %% [markdown]
# В этом количестве случаев температура была ниже 1500 градусов. Это сбой / ошибка в процессе или ошибка измерения?

# %% [markdown]
# Посмотрим на эти записи:

# %%
t_list = data_temp.loc[data_temp['Температура'] <= 1500]['key'].to_list()

# %%
for t in t_list: 
    display(t)
    display(data_arc.loc[data_arc['key']==t])
    display(data_bulk.loc[data_bulk['key']==t])  
    display(data_bulk_time.loc[data_bulk_time['key']==t])
    display(data_gas.loc[data_gas['key']==t])
# Out:
# 867
#       key  \
# 4028  867
# 4029  867
# 4030  867
# 4031  867
# 4032  867
# 4033  867
# 4034  867
#
#      Начало нагрева дугой  \
# 4028  2019-06-04 14:17:51
# 4029  2019-06-04 14:33:04
# 4030  2019-06-04 14:36:50
# 4031  2019-06-04 14:39:23
# 4032  2019-06-04 14:44:01
# 4033  2019-06-04 14:48:06
# 4034  2019-06-04 14:54:19
#
#      Конец нагрева дугой  \
# 4028 2019-06-04 14:20:06
# 4029 2019-06-04 14:35:39
# 4030 2019-06-04 14:37:49
# 4031 2019-06-04 14:41:13
# 4032 2019-06-04 14:47:10
# 4033 2019-06-04 14:52:20
# 4034 2019-06-04 14:55:26
#
#       Активная мощность  \
# 4028           0.470265
# 4029           0.546894
# 4030           0.217033
# 4031           0.446139
# 4032           0.815899
# 4033           1.133725
# 4034           0.278104
#
#       Реактивная мощность
# 4028             0.342909
# 4029             0.401882
# 4030             0.157679
# 4031             0.383610
# 4032             0.591709
# 4033             0.781918
# 4034             0.189851
# ...

# %% [markdown]
# Для каких-то из этих key мы видим бОльшее количество циклов нагрева, для каких-то меньшее. То же касается и добавок, и газа: явной закономерности не выявить. Пока не будем удалять эти данные, посмотрим, как это скажется на моделях.

# %% [markdown]
# __Среднее изменение температуры в каждой партии__

# %%
temp_min = pd.DataFrame(data_temp.groupby('key')['Температура'].min().reset_index())
temp_max = pd.DataFrame(data_temp.groupby('key')['Температура'].max().reset_index())
temp_diff = temp_min.join(temp_max['Температура'], lsuffix='_min', rsuffix='_max')
temp_diff['Разница'] = temp_diff['Температура_max'] - temp_diff['Температура_min']
temp_diff.sort_values(by='Разница', ascending=False)
# Out:
#        key  \
# 855    867
# 1604  1619
# 1201  1214
# 2036  2052
# 1803  1818
# ...    ...
# 2722  2746
# 2723  2747
# 2724  2748
# 2725  2749
# 3215  3241
#
#       Температура_min  \
# 855            1191.0
# 1604           1218.0
# 1201           1208.0
# 2036           1227.0
# 1803           1383.0
# ...               ...
# 2722           1596.0
# 2723           1626.0
# 2724           1623.0
# 2725           1582.0
# 3215           1586.0
#
#       Температура_max  \
# 855            1600.0
# 1604           1623.0
# 1201           1608.0
# 2036           1592.0
# 1803           1680.0
# ...               ...
# 2722           1596.0
# 2723           1626.0
# 2724           1623.0
# 2725           1582.0
# 3215           1586.0
#
#       Разница
# 855     409.0
# 1604    405.0
# 1201    400.0
# 2036    365.0
# 1803    297.0
# ...       ...
# 2722      0.0
# 2723      0.0
# 2724      0.0
# 2725      0.0
# 3215      0.0
#
# [3216 rows x 4 columns]

# %% [markdown]
# Для некоторых keys температура не изменилась. Или измерения были неверными? Или потерялись данные?

# %%
data_temp.loc[data_temp['Температура'].isna()]
# Out:
#         key  \
# 12268  2500
# 12269  2500
# 12270  2500
# 12272  2501
# 12273  2501
# ...     ...
# 15901  3240
# 15903  3241
# 15904  3241
# 15905  3241
# 15906  3241
#
#               Время замера  \
# 12268  2019-08-06 03:24:43
# 12269  2019-08-06 03:25:16
# 12270  2019-08-06 03:28:21
# 12272  2019-08-06 04:01:59
# 12273  2019-08-06 04:14:35
# ...                    ...
# 15901  2019-09-01 03:35:16
# 15903  2019-09-01 04:16:12
# 15904  2019-09-01 04:22:39
# 15905  2019-09-01 04:33:42
# 15906  2019-09-01 04:38:08
#
#        Температура
# 12268          NaN
# 12269          NaN
# 12270          NaN
# 12272          NaN
# 12273          NaN
# ...            ...
# 15901          NaN
# 15903          NaN
# 15904          NaN
# 15905          NaN
# 15906          NaN
#
# [2901 rows x 3 columns]

# %% [markdown]
# Возможно, норма, что на последних этапах отсутсвуют измерения финальной температуры.

# %% [markdown]
# Удалим данные с нулями и посмотрим на распределение температуры:

# %%
temp_diff_dropped = temp_diff.drop(temp_diff.loc[temp_diff['Разница'] == 0.0].index)
temp_diff_dropped
# Out:
#        key  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 2472  2495
# 2473  2496
# 2474  2497
# 2475  2498
# 2476  2499
#
#       Температура_min  \
# 0              1571.0
# 1              1577.0
# 2              1596.0
# 3              1601.0
# 4              1576.0
# ...               ...
# 2472           1570.0
# 2473           1554.0
# 2474           1571.0
# 2475           1570.0
# 2476           1569.0
#
#       Температура_max  \
# 0              1618.0
# 1              1608.0
# 2              1599.0
# 3              1625.0
# 4              1602.0
# ...               ...
# 2472           1591.0
# 2473           1595.0
# 2474           1589.0
# 2475           1594.0
# 2476           1604.0
#
#       Разница
# 0        47.0
# 1        31.0
# 2         3.0
# 3        24.0
# 4        26.0
# ...       ...
# 2472     21.0
# 2473     41.0
# 2474     18.0
# 2475     24.0
# 2476     35.0
#
# [2472 rows x 4 columns]

# %%
plt.figure(figsize=(8,4))
sns.boxplot(temp_diff_dropped['Разница'], color='dimgray')
plt.title('Изменение температуры', size=16);

# %%
temp_diff_dropped[temp_diff_dropped['Разница'] > 290]
# Out:
#        key  \
# 855    867
# 1201  1214
# 1604  1619
# 1803  1818
# 2036  2052
#
#       Температура_min  \
# 855            1191.0
# 1201           1208.0
# 1604           1218.0
# 1803           1383.0
# 2036           1227.0
#
#       Температура_max  \
# 855            1600.0
# 1201           1608.0
# 1604           1623.0
# 1803           1680.0
# 2036           1592.0
#
#       Разница
# 855     409.0
# 1201    400.0
# 1604    405.0
# 1803    297.0
# 2036    365.0

# %% [markdown]
# Очевидно, что это почти все те же самые key, что были найдены нами выше.

# %% [markdown]
# ### Данные о проволочных материалах (объём)

# %% [markdown]
# __data_wire.csv__ — данные о проволочных материалах (объём)

# %%
try: 
    data_wire = pd.read_csv('/datasets/data_wire.csv')
    
except: 
    data_wire = pd.read_csv('datasets/data_wire.csv')
    
df_info(data_wire)
# Out:
# (3081, 10)
#    key     Wire 1  \
# 0    1  60.059998
# 1    2  96.052315
# 2    3  91.160157
# 3    4  89.063515
# 4    5  89.238236
#
#     Wire 2  \
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4  9.11456
#
#    Wire 3  Wire 4  \
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
#
#    Wire 5  Wire 6  \
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
#
#    Wire 7  Wire 8  \
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
#
#    Wire 9
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   float64
#  2   Wire 2  1079 non-null   float64
# ...

# %% [markdown]
# - В расплавленный металл могут подавать 9 различных проволочных материалов.
# - В основном в ход идет проволока № 1 и, в меньшей степени, 2.
# - Остальных видов используют намного меньше.
# - Партий, в которые не подавали вообще ни одного вида проволоки, нет.

# %% [markdown]
# ### Данные о проволочных материалах (время)

# %% [markdown]
# __data_wire_time.csv__ — данные о проволочных материалах (время).

# %%
try: 
    data_wire_time = pd.read_csv('/datasets/data_wire_time.csv')
    
except: 
    data_wire_time = pd.read_csv('datasets/data_wire_time.csv')
    
df_info(data_wire_time)
# Out:
# (3081, 10)
#    key  \
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
#
#                 Wire 1  \
# 0  2019-05-03 11:11:41
# 1  2019-05-03 11:46:10
# 2  2019-05-03 12:13:47
# 3  2019-05-03 12:48:05
# 4  2019-05-03 13:18:15
#
#                 Wire 2  \
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4  2019-05-03 13:32:06
#
#   Wire 3 Wire 4  \
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN
#
#   Wire 5 Wire 6  \
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN
#
#   Wire 7 Wire 8  \
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN
#
#   Wire 9
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
# ...

# %% [markdown]
# Возможно, данные о времени понядобятся для моделей машинного обучения.

# %% [markdown]
# __Таким образом:__

# %% [markdown]
# - Мы получили и кратко рассмотрели данные о частях производственного процесса из 7 различных датасетов.
# - Будем переходить к предобработке данных и их подготовке для машинного обучения.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Формат даты/времени

# %%
for column in data_bulk_time.columns[1:]:
    datetime(data_bulk_time, column)

# %%
for column in data_wire_time.columns[1:]:
    datetime(data_wire_time, column)

# %%
datetime(data_temp, 'Время замера')

# %% [markdown]
# ### Добавление данных в датасет об электродах

# %% [markdown]
# Заведем список датасетов, которые мы потом будем, объединять в один, чтобы ничего не потерять:

# %%
datasets_to_merge_list=[]

# %% [markdown]
# Добавим в таблицу данные о полной мощности, которая рассчитывается как квадратный корень из суммы квадратов активной и реактивной мощностей.

# %% [markdown]
# Формат даты мы уже исправили, а также удалили единственный большой выброс.

# %%
data_arc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14875 entries, 0 to 14875
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   key                   14875 non-null  int64
#  1   Начало нагрева дугой  14875 non-null  datetime64[ns]
#  2   Конец нагрева дугой   14875 non-null  datetime64[ns]
#  3   Активная мощность     14875 non-null  float64
#  4   Реактивная мощность   14875 non-null  float64
# dtypes: datetime64[ns](2), float64(2), int64(1)
# memory usage: 697.3 KB

# %%
data_arc['full_power'] = np.sqrt(data_arc['Активная мощность']**2 + data_arc['Реактивная мощность']**2)

# %%
data_arc_updated = data_arc.drop(['Начало нагрева дугой', 'Конец нагрева дугой'], axis=1)
data_arc_updated.head()
# Out:
#    key  \
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
#
#    Активная мощность  \
# 0           0.976059
# 1           0.805607
# 2           0.744363
# 3           1.659363
# 4           0.692755
#
#    Реактивная мощность  \
# 0             0.687084
# 1             0.520285
# 2             0.498805
# 3             1.062669
# 4             0.414397
#
#    full_power
# 0    1.193639
# 1    0.959010
# 2    0.896038
# 3    1.970470
# 4    0.807239

# %%
data_arc_pivot = data_arc_updated.groupby('key')['full_power', 'Активная мощность', 'Реактивная мощность'].sum().reset_index()

# %%
data_arc_pivot.head()
# Out:
#    key  \
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
#
#    full_power  \
# 0    5.826395
# 1    3.649216
# 2    2.989534
# 3    3.814962
# 4    4.035758
#
#    Активная мощность  \
# 0           4.878147
# 1           3.052598
# 2           2.525882
# 3           3.209250
# 4           3.347173
#
#    Реактивная мощность
# 0             3.183241
# 1             1.998112
# 2             1.599076
# 3             2.060298
# 4             2.252643

# %%
data_arc_pivot.columns=['key', 'full_power', 'active_power', 'reactive_power']

# %%
datasets_to_merge_list.append(data_arc_pivot)

# %%
data_gas.columns=['key', 'gas']

# %%
datasets_to_merge_list.append(data_gas)

# %% [markdown]
# ### Данные о температуре - выделение целевого признака

# %% [markdown]
# Придется удалить из датасета все данные, у которых:
# - нет финального замера (т.е. замер температуры до окончания последней операции нагрева дугой),
# - вообще только один замер температуры

# %%
temp_key_group = data_temp.groupby('key')['Температура'].count().reset_index()
temp_key_group['Температура'].value_counts().sort_values(ascending=False)
# Out:
# 1     741
# 4     650
# 5     585
# 3     432
# 6     370
# 7     182
# 8     100
# 2      56
# 9      43
# 10     21
# 11     16
# 12     12
# 16      4
# 15      2
# 14      1
# 13      1
# Name: Температура, dtype: int64

# %% [markdown]
# 741 запись имеет только один замер температуры

# %%
keys_to_delete = temp_key_group.loc[temp_key_group['Температура'] == 1]['key'].to_list()
len(keys_to_delete)
# Out:
# 741

# %%
data_temp_updated = data_temp.drop(
    data_temp[data_temp['key'].isin(keys_to_delete)].index
)

# %% [markdown]
# Вот столько записей из датасета мы при этом потеряли:

# %%
data_temp.shape[0]-data_temp_updated.shape[0]
# Out:
# 3642

# %% [markdown]
# При этом больше не осталось записей с одним замером:

# %%
temp_key_group_1 = data_temp_updated.groupby('key')['Температура'].count().reset_index()
(temp_key_group_1['Температура']==1).sum()
# Out:
# 0

# %% [markdown]
# Теперь найдем самую первую по времени и самую последнюю по времени температуру в группе по key.

# %%
keys = data_temp_updated['key'].unique()
len(keys)
# Out:
# 2475

# %%
temp_start_final = pd.DataFrame(columns=['key','temp_start', 'temp_final'])
i = 0
for key in keys:   
    row = data_temp_updated.query('key == @key').reset_index()
    start = row['Температура'].tolist()[0]
    final = row['Температура'].tolist()[-1]
    
    temp_start_final.loc[i, 'key'] = key
    temp_start_final.loc[i, 'temp_start'] = start
    temp_start_final.loc[i, 'temp_final'] = final
    
    i += 1

# %%
display(temp_start_final.head(5))
display(temp_start_final.isna().sum())
display(temp_start_final.shape)
# Out:
#   key temp_start  \
# 0   1     1571.0
# 1   2     1581.0
# 2   3     1596.0
# 3   4     1601.0
# 4   5     1576.0
#
#   temp_final
# 0     1613.0
# 1     1602.0
# 2     1599.0
# 3     1625.0
# 4     1602.0
# key           0
# temp_start    0
# temp_final    0
# dtype: int64
# (2475, 3)

# %% [markdown]
# Для проверки посмотрим на один любой key:

# %%
temp_start_final[temp_start_final['key'] == 116]
# Out:
#      key  \
# 113  116
#
#     temp_start  \
# 113     1591.0
#
#     temp_final
# 113     1600.0

# %%
data_temp_updated[data_temp_updated['key'] == 116]
# Out:
#      key  \
# 665  116
# 666  116
# 667  116
# 668  116
#
#            Время замера  \
# 665 2019-05-07 13:34:41
# 666 2019-05-07 13:48:34
# 667 2019-05-07 13:55:30
# 668 2019-05-07 14:02:33
#
#      Температура
# 665       1591.0
# 666       1587.0
# 667       1594.0
# 668       1600.0

# %% [markdown]
# В действительности найденное нами самое раннее и самое позднее значение температуры совпадают.

# %% [markdown]
# - temp_start - это один из feature признаков
# - temp_final - это целевой признак, target

# %% [markdown]
# ### Данные о температуре - добавление features

# %% [markdown]
# __Добавим признак: время между стартовым и финальным замерами температуры.__

# %% [markdown]
# Возьмем его из необработанного датасета, а потом, когда будем, собирать все датасеты в один, оставим все равно только те keys, для которых есть данные в temp_start_final.

# %%
temp_time = pd.DataFrame(
    data_temp.groupby('key')['Время замера'].min()
).join(data_temp.groupby('key')['Время замера'].max(), lsuffix='_начало', rsuffix='_окончание'
      ).reset_index()
temp_time['heating_seconds'] = (temp_time['Время замера_окончание'] - temp_time['Время замера_начало']).dt.seconds
temp_time = temp_time[['key', 'heating_seconds']]
temp_time.head()
# Out:
#    key  \
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
#
#    heating_seconds
# 0              861
# 1             1305
# 2             1300
# 3              388
# 4              762

# %%
datasets_to_merge_list.append(temp_time)

# %%
#time_delta_seconds_dict = dict(zip(list(temp_time['key']), list(temp_time['time_delta_seconds'])))

# %% [markdown]
# ### Данные о работе электродов - добавление features

# %% [markdown]
# __Добавим признак: время, которое электроды были активны__

# %%
data_arc.head()
# Out:
#    key  \
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
#
#   Начало нагрева дугой  \
# 0  2019-05-03 11:02:14
# 1  2019-05-03 11:07:28
# 2  2019-05-03 11:11:44
# 3  2019-05-03 11:18:14
# 4  2019-05-03 11:26:09
#
#   Конец нагрева дугой  \
# 0 2019-05-03 11:06:02
# 1 2019-05-03 11:10:33
# 2 2019-05-03 11:14:36
# 3 2019-05-03 11:24:19
# 4 2019-05-03 11:28:37
#
#    Активная мощность  \
# 0           0.976059
# 1           0.805607
# 2           0.744363
# 3           1.659363
# 4           0.692755
#
#    Реактивная мощность  \
# 0             0.687084
# 1             0.520285
# 2             0.498805
# 3             1.062669
# 4             0.414397
#
#    full_power
# 0    1.193639
# 1    0.959010
# 2    0.896038
# 3    1.970470
# 4    0.807239

# %%
data_arc['el_work_time_seconds'] = (data_arc['Конец нагрева дугой'] - data_arc['Начало нагрева дугой']).dt.seconds
electrode_time_sum = data_arc.groupby('key')['el_work_time_seconds'].sum().reset_index()
electrode_time_sum.head()
# Out:
#    key  \
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
#
#    el_work_time_seconds
# 0                  1098
# 1                   811
# 2                   655
# 3                   741
# 4                   869

# %%
datasets_to_merge_list.append(electrode_time_sum)

# %%
#el_work_time_dict = dict(zip(list(electrode_time_sum['key']), list(electrode_time_sum['el_work_time_seconds'])))

# %% [markdown]
# __Добавим признак: сколько итераций нагрева было для каждой партии__

# %%
data_arc
# Out:
#         key  \
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 14871  3241
# 14872  3241
# 14873  3241
# 14874  3241
# 14875  3241
#
#       Начало нагрева дугой  \
# 0      2019-05-03 11:02:14
# 1      2019-05-03 11:07:28
# 2      2019-05-03 11:11:44
# 3      2019-05-03 11:18:14
# 4      2019-05-03 11:26:09
# ...                    ...
# 14871  2019-09-01 03:58:58
# 14872  2019-09-01 04:05:04
# 14873  2019-09-01 04:16:41
# 14874  2019-09-01 04:31:51
# 14875  2019-09-01 04:34:47
#
#       Конец нагрева дугой  \
# 0     2019-05-03 11:06:02
# 1     2019-05-03 11:10:33
# 2     2019-05-03 11:14:36
# 3     2019-05-03 11:24:19
# 4     2019-05-03 11:28:37
# ...                   ...
# 14871 2019-09-01 04:01:35
# 14872 2019-09-01 04:08:04
# 14873 2019-09-01 04:19:45
# 14874 2019-09-01 04:32:48
# 14875 2019-09-01 04:36:08
#
#        Активная мощность  \
# 0               0.976059
# 1               0.805607
# 2               0.744363
# ...

# %%
el_iter = data_arc.groupby('key')['el_work_time_seconds'].count().reset_index()
el_iter.columns=['key', 'el_work_iterations']
el_iter.head()
# Out:
#    key  \
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
#
#    el_work_iterations
# 0                   5
# 1                   4
# 2                   5
# 3                   4
# 4                   4

# %%
datasets_to_merge_list.append(el_iter)

# %% [markdown]
# ### Данные о проволочных материалах - добавление features

# %%
data_wire = data_wire.fillna(0)
data_wire['total_wire'] = data_wire['Wire 1'] + data_wire['Wire 2'] + data_wire['Wire 3'] + data_wire['Wire 4'] + data_wire['Wire 5'] + data_wire['Wire 6'] + data_wire['Wire 7'] + data_wire['Wire 8'] + data_wire['Wire 9']

# %% [markdown]
# Количество подач проволоки:

# %%
counter=0
qty_list=[]
for i in range (0, data_wire.shape[0]): 
    for column in data_wire.columns[1:10]: 
        if data_wire.iloc[i][column]!=0: 
            counter=counter+1
    qty_list.append(counter)
    counter = 0

# %%
data_wire['qty_wire']=pd.Series(qty_list)

# %%
#wire_qty_dict=dict(zip(list(data_wire['key']), qty_list))

# %%
data_wire_updated = data_wire[['key', 'qty_wire', 'total_wire']]

# %%
data_wire_updated.head()
# Out:
#    key  qty_wire  \
# 0    1         1
# 1    2         1
# 2    3         1
# 3    4         1
# 4    5         2
#
#    total_wire
# 0   60.059998
# 1   96.052315
# 2   91.160157
# 3   89.063515
# 4   98.352796

# %%
datasets_to_merge_list.append(data_wire_updated)

# %% [markdown]
# ### Данные о подаче сыпучих материалов (шлака) - добавление features

# %% [markdown]
# Поступим также, как и с проволокой

# %%
data_bulk = data_bulk.fillna(0)
data_bulk['total_bulk'] = data_bulk['Bulk 1'] + data_bulk['Bulk 2'] +data_bulk ['Bulk 3'] + data_bulk['Bulk 4'] +data_bulk['Bulk 5'] + data_bulk['Bulk 6'] + data_bulk['Bulk 7'] +data_bulk ['Bulk 8'] + data_bulk['Bulk 9'] +data_bulk['Bulk 10'] + data_bulk['Bulk 11'] + data_bulk['Bulk 12'] +data_bulk ['Bulk 13'] + data_bulk['Bulk 14'] +data_bulk['Bulk 15']

# %%
#bulk_dict = dict(zip(list(data_bulk['key']), list(data_bulk['total_bulk'])))

# %% [markdown]
# Количество подач шлака:

# %%
counter=0
qty_list_1=[]
for i in range (0, data_bulk.shape[0]): 
    for column in data_bulk.columns[1:16]: 
        if data_bulk.iloc[i][column]!=0: 
            counter=counter+1
    qty_list_1.append(counter)
    counter = 0

# %%
data_bulk_qty = data_bulk[['key', 'total_bulk']]
data_bulk_qty['qty_of_bulks'] = pd.Series(qty_list_1)

# %%
datasets_to_merge_list.append(data_bulk_qty)

# %% [markdown]
# ### Объединение таблиц

# %%
for dataset in datasets_to_merge_list: 
    display(dataset)
# Out:
#        key  \
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ...    ...
# 3209  3237
# 3210  3238
# 3211  3239
# 3212  3240
# 3213  3241
#
#       full_power  \
# 0       5.826395
# 1       3.649216
# 2       2.989534
# 3       3.814962
# 4       4.035758
# ...          ...
# 3209    4.844982
# 3210    2.696542
# 3211    5.611883
# 3212    3.891856
# 3213    2.999516
#
#       active_power  \
# 0         4.878147
# 1         3.052598
# 2         2.525882
# 3         3.209250
# 4         3.347173
# ...            ...
# 3209      3.932467
# 3210      2.106529
# 3211      4.666754
# 3212      2.984083
# 3213      2.471447
#
#       reactive_power
# 0           3.183241
# 1           1.998112
# 2           1.599076
# 3           2.060298
# 4           2.252643
# ...              ...
# 3209        2.828459
# 3210        1.681182
# 3211        3.111617
# 3212        2.483267
# 3213        1.696199
#
# [3214 rows x 4 columns]
#        key  \
# 0        1
# 1        2
# ...

# %%
full_data = temp_start_final.copy()

# %%
full_data.shape
# Out:
# (2475, 3)

# %%
for dataset in datasets_to_merge_list: 
    full_data = full_data.merge(dataset, how='left', on='key')

# %%
df_info(full_data)
# Out:
# (2475, 14)
#   key temp_start  \
# 0   1     1571.0
# 1   2     1581.0
# 2   3     1596.0
# 3   4     1601.0
# 4   5     1576.0
#
#   temp_final  \
# 0     1613.0
# 1     1602.0
# 2     1599.0
# 3     1625.0
# 4     1602.0
#
#    full_power  \
# 0    5.826395
# 1    3.649216
# 2    2.989534
# 3    3.814962
# 4    4.035758
#
#    active_power  \
# 0      4.878147
# 1      3.052598
# 2      2.525882
# 3      3.209250
# 4      3.347173
#
#    reactive_power  \
# 0        3.183241
# 1        1.998112
# 2        1.599076
# 3        2.060298
# 4        2.252643
#
#          gas  \
# 0  29.749986
# 1  12.555561
# 2  28.554793
# 3  18.841219
# 4   5.413692
#
#    heating_seconds  \
# 0              861
# 1             1305
# 2             1300
# 3              388
# 4              762
#
#    el_work_time_seconds  \
# 0                  1098
# 1                   811
# 2                   655
# 3                   741
# 4                   869
#
#    el_work_iterations  \
# ...

# %%
full_data['temp_start'] = full_data['temp_start'].astype('int')
full_data['temp_final'] = full_data['temp_final'].astype('int')

# %%
full_data = full_data.fillna(0)

# %%
full_data.describe().T
# Out:
#                        count  \
# key                   2475.0
# temp_start            2475.0
# temp_final            2475.0
# full_power            2475.0
# active_power          2475.0
# reactive_power        2475.0
# gas                   2475.0
# heating_seconds       2475.0
# el_work_time_seconds  2475.0
# el_work_iterations    2475.0
# qty_wire              2475.0
# total_wire            2475.0
# total_bulk            2475.0
# qty_of_bulks          2475.0
#
#                              mean  \
# key                   1250.787071
# temp_start            1588.402020
# temp_final            1595.336162
# full_power               3.909335
# active_power             3.127428
# reactive_power           2.330686
# gas                     11.133956
# heating_seconds       1854.953939
# el_work_time_seconds   799.907879
# el_work_iterations       4.625455
# qty_wire                 1.342222
# total_wire             120.071526
# total_bulk             587.178182
# ...

# %% [markdown]
# ### Исследовательский анализ сборного датасета

# %%
correlation = full_data.corr()
correlation
# Out:
#                            key  \
# key                   1.000000
# temp_start           -0.017691
# temp_final           -0.081162
# full_power           -0.022532
# active_power         -0.036510
# reactive_power        0.000332
# gas                  -0.034823
# heating_seconds      -0.001182
# el_work_time_seconds -0.034212
# el_work_iterations   -0.034834
# qty_wire              0.038367
# total_wire            0.011686
# total_bulk           -0.022366
# qty_of_bulks          0.023285
#
#                       temp_start  \
# key                    -0.017691
# temp_start              1.000000
# temp_final              0.376621
# full_power             -0.322952
# active_power           -0.325273
# reactive_power         -0.310308
# gas                    -0.001326
# heating_seconds         0.125857
# el_work_time_seconds   -0.295503
# el_work_iterations     -0.176337
# qty_wire               -0.154285
# total_wire              0.001077
# total_bulk             -0.132606
# ...

# %%
num_corr(full_data)

# %%
#версия scatterplot для черно-белой печати
#plt.figure(figsize=(13,13))
#sns.heatmap(correlation, center=0, annot=True, cmap='Greys', square=True, linewidths=.5, cbar_kws={"shrink": .5})
#plt.title('Корреляция финального датасета', size=16);

# %% [markdown]
# <div class="alert alert-danger">
# <b>ВЫВОДЫ</b></div>

# %% [markdown]
# - На финальную температуру заметно влияют затраченная мощность, длительность работы электродов и начальная температура. Что, в целом, логично.
# - Корреляция не обнаружена между финальной температурой и тремя признаками: временем между замерами температуры, объемом инертного газа и количеством потраченной проволоки.
#
# - Данные готовы для машинного обучения. Составляем выводы и обучаем модели.
#
# Вывод
# - Провели этап подготовки данных.
#
# - Удалили заметный выброс мощности, очистили температуру от ненужных записей, перевели количество сыпучих добавок и затраченной проволоки в суммарный объем. Перевели данные в удобный вид.
# - Добавили три новые фичи: полная мощность, время работы электродов, количество включений электродов.
#
# - Соединили таблицы в один датасет df_full.
# - Замечены корреляции между целевым признаком и параметрами работы электродов. Количество добавок и газа практически не влияет на изменение финальной температуры.
#
# - Переходим к машинному обучению.

# %% [markdown]
# ### Поиск выбросов по совокупности feature

# %% [markdown]
# Поищем выбросы в итоговом датасете по совокупности признаков с помощью IsolationForest:

# %%
data_for_forest = full_data.drop('key', axis=1)
data_for_forest.head()
# Out:
#    temp_start  \
# 0        1571
# 1        1581
# 2        1596
# 3        1601
# 4        1576
#
#    temp_final  \
# 0        1613
# 1        1602
# 2        1599
# 3        1625
# 4        1602
#
#    full_power  \
# 0    5.826395
# 1    3.649216
# 2    2.989534
# 3    3.814962
# 4    4.035758
#
#    active_power  \
# 0      4.878147
# 1      3.052598
# 2      2.525882
# 3      3.209250
# 4      3.347173
#
#    reactive_power  \
# 0        3.183241
# 1        1.998112
# 2        1.599076
# 3        2.060298
# 4        2.252643
#
#          gas  \
# 0  29.749986
# 1  12.555561
# 2  28.554793
# 3  18.841219
# 4   5.413692
#
#    heating_seconds  \
# 0              861
# 1             1305
# 2             1300
# 3              388
# 4              762
#
#    el_work_time_seconds  \
# 0                  1098
# 1                   811
# 2                   655
# 3                   741
# 4                   869
#
#    el_work_iterations  \
# 0                   5
# ...

# %%
iso_model = IsolationForest(n_estimators=100, random_state=rs)
estimation_iforest = iso_model.fit_predict(data_for_forest) == -1
outliers_iforest = estimation_iforest.sum()
print("Количество аномалий (изоляционный лес): ", outliers_iforest)
print('Доля аномалий (изоляционный лес), %: ', '{0:.2f}\n'.format((outliers_iforest /data_for_forest.shape[0])*100))
# Out:
# Количество аномалий (изоляционный лес):  297
# Доля аномалий (изоляционный лес), %:  12.00

# %%
anomaly_scores = iso_model.decision_function(data_for_forest)

# %%
data_for_forest['anomaly_scores']=pd.Series(anomaly_scores)

# %%
data_for_forest.head()
# Out:
#    temp_start  \
# 0        1571
# 1        1581
# 2        1596
# 3        1601
# 4        1576
#
#    temp_final  \
# 0        1613
# 1        1602
# 2        1599
# 3        1625
# 4        1602
#
#    full_power  \
# 0    5.826395
# 1    3.649216
# 2    2.989534
# 3    3.814962
# 4    4.035758
#
#    active_power  \
# 0      4.878147
# 1      3.052598
# 2      2.525882
# 3      3.209250
# 4      3.347173
#
#    reactive_power  \
# 0        3.183241
# 1        1.998112
# 2        1.599076
# 3        2.060298
# 4        2.252643
#
#          gas  \
# 0  29.749986
# 1  12.555561
# 2  28.554793
# 3  18.841219
# 4   5.413692
#
#    heating_seconds  \
# 0              861
# 1             1305
# 2             1300
# 3              388
# 4              762
#
#    el_work_time_seconds  \
# 0                  1098
# 1                   811
# 2                   655
# 3                   741
# 4                   869
#
#    el_work_iterations  \
# 0                   5
# ...

# %% [markdown]
# Посмотрим распределение anomaly_scores в датасете:

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.distplot(data_for_forest['anomaly_scores'], color='dimgrey')
plt.xlabel('Anomaly scores', size=12)
plt.ylabel('Scores', size=12)
plt.title('Распределение выбросов и отклонений согласно Isolation Forest', size=14);

# %% [markdown]
# Посмотрим распределение anomaly_scores у тех, кого модель признала "выбросом"

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.distplot(data_for_forest[iso_model.fit_predict(data_for_forest) == -1]['anomaly_scores'], color='dimgrey')
plt.xlabel('Anomaly scores', size=12)
plt.ylabel('Scores', size=12)
plt.title('Распределение выбросов и отклонений согласно Isolation Forest', size=14);

# %% [markdown]
# В основном, anomaly_scores находятся в ближней к нулю стороне отрезка [-0.5,0]. <div>
# Сейчас не будем искать и удалять никакие выбросы, данных и так не очень много. <div>
# Посмотрим, какие результаты покажут модели.

# %% [markdown]
# ## Подготовка признаков для моделей

# %% [markdown]
# ### Разделение на обучающую и тестовую выборки

# %% [markdown]
# Будем использовать две выборки: обучающую и тестовую с использованием кросс-валидации.

# %%
full_data.head(3)
# Out:
#    key  \
# 0    1
# 1    2
# 2    3
#
#    temp_start  \
# 0        1571
# 1        1581
# 2        1596
#
#    temp_final  \
# 0        1613
# 1        1602
# 2        1599
#
#    full_power  \
# 0    5.826395
# 1    3.649216
# 2    2.989534
#
#    active_power  \
# 0      4.878147
# 1      3.052598
# 2      2.525882
#
#    reactive_power  \
# 0        3.183241
# 1        1.998112
# 2        1.599076
#
#          gas  \
# 0  29.749986
# 1  12.555561
# 2  28.554793
#
#    heating_seconds  \
# 0              861
# 1             1305
# 2             1300
#
#    el_work_time_seconds  \
# 0                  1098
# 1                   811
# 2                   655
#
#    el_work_iterations  \
# 0                   5
# 1                   4
# 2                   5
#
#    qty_wire  \
# 0       1.0
# 1       1.0
# 2       1.0
#
#    total_wire  \
# 0   60.059998
# 1   96.052315
# 2   91.160157
#
#    total_bulk  \
# 0       553.0
# 1       582.0
# 2       544.0
#
#    qty_of_bulks
# ...

# %%
features = full_data.drop(['key','temp_final'], axis=1)
target = full_data['temp_final']

# %%
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=.2, random_state=rs)

# %%
features_train.shape, features_test.shape, target_train.shape, target_test.shape
# Out:
# ((1980, 12), (495, 12), (1980,), (495,))

# %% [markdown]
# ### Dummy модель

# %%
dummy_model = DummyRegressor(strategy="median")
dummy_model.fit(features_train, target_train)
# Out:
# DummyRegressor(strategy='median')

# %%
prediction_train(dummy_model, features_train, target_train)
# Out:
# MAE на обучающей выборке 9.801

# %%
# %%time
prediction_test(dummy_model, features_test, target_test)
# Out:
# MAE на тестовой выборке 10.277
# Wall time: 0 ns

# %% [markdown]
# ## Выбор и обучение моделей

# %% [markdown]
# ### Linear Regression

# %%
model_number = 0
model_name = 'Linear Regression'

# %%
model_lr = LinearRegression(n_jobs=-1)

# %%
# %%time
start = time.time()
model_lr.fit(features_train, target_train)
time_learn = round((time.time() - start), 4)
# Out:
# Wall time: 0 ns

# %%
cv_score(model_lr, features_train, target_train)
# Out:
# Результат кросс валидации [-7.35111071 -7.55304898 -7.9946756  -7.7756934  -6.92145876]
# Результат средний -7.519

# %%
prediction_train(model_lr, features_train, target_train)
# Out:
# MAE на обучающей выборке 7.447

# %%
results_upd_train(model_number, model_name, time_learn, train_mae(lr_model))
# Out:
#                model  \
# 0  Linear Regression
#
#   time_learn, ms  \
# 0            0.0
#
#   time_predict, ms  \
# 0              NaN
#
#   mae_train  \
# 0  7.446701
#
#   mae_test
# 0      NaN

# %% [markdown]
# ### Random Forest Regressor

# %%
model_number = 1
model_name = 'Random Forest Regressor'

# %%
model_rfr = RandomForestRegressor(random_state=rs, n_jobs=-1)
rfr_params = dict(n_estimators=[100,200,300,400,500],
                  max_depth=[3,5,7,9],
                  criterion=['mae','mse'])

# %%
# %%time
# grid_search(model_rfr, rfr_params, features_train, target_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# -6.288850903517391
# {'criterion': 'mse', 'max_depth': 9, 'n_estimators': 400}
# Wall time: 29min 20s

# %% [markdown]
# Ячейка выше закомментирована, т.к. поиск параметров занял 29 минут. Вывод ячейки при этом следующий:
# - Fitting 5 folds for each of 40 candidates, totalling 200 fits
# - -6.288850903517391
# - {'criterion': 'mse', 'max_depth': 9, 'n_estimators': 400}
# - Wall time: 29min 20s

# %% [markdown]
# Обучим случайный лес с этими параметрами и посмотрим на результат.

# %%
model_rfr = RandomForestRegressor(n_estimators=400, max_depth=9, criterion='mse', random_state=rs, n_jobs=-1)

# %%
start = time.time()
model_rfr.fit(features_train, target_train)
time_learn = round((time.time() - start), 4)
time_learn
# Out:
# 1.4367

# %%
cv_score(model_rfr, features_train, target_train)
# Out:
# Результат кросс валидации [-6.36580385 -6.11233757 -6.60042931 -6.02989259 -6.3357912 ]
# Результат средний -6.289

# %%
# %%time
prediction_train(model_rfr, features_train, target_train)
# Out:
# MAE на обучающей выборке 4.352
# Wall time: 70.3 ms

# %%
train_mae(model_rfr)
# Out:
# 4.352365191909319

# %%
results_upd_train(model_number, model_name, time_learn, train_mae(model_rfr))
# Out:
#                      model  \
# 0        Linear Regression
# 1  Random Forest Regressor
#
#   time_learn, ms  \
# 0            0.0
# 1         1.4367
#
#   time_predict, ms  \
# 0              NaN
# 1              NaN
#
#   mae_train  \
# 0  7.446701
# 1  4.352365
#
#   mae_test
# 0      NaN
# 1      NaN

# %% [markdown]
# ### Gradient Boosting Regregressor

# %%
model_number = 2
model_name = 'Gradient Boosting Regregressor'

# %%
model_gbr_1 = GradientBoostingRegressor(random_state=rs, learning_rate=0.01)
model_gbr_params_1 = dict(n_estimators=[100,300,500,600])
model_gbr_params_2 = dict(max_depth=[5,7,9],
                    subsample=[0.9, 0.8, 0.7])

# %%
#grid_search(model_gbr_1, model_gbr_params_1, features_train, target_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# -6.189960198847314
# {'n_estimators': 600}

# %% [markdown]
# В закомментированной ячейке выше найдены следующие лучшие параметры:
# - Fitting 5 folds for each of 4 candidates, totalling 20 fits
# - -6.189960198847314
# - {'n_estimators': 600}

# %%
model_gbr_2 = GradientBoostingRegressor(n_estimators=600, random_state=rs)

# %%
#grid_search(model_gbr_2, model_gbr_params_2, features_train, target_train)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# -6.0737250986537425
# {'max_depth': 5, 'subsample': 0.9}

# %% [markdown]
# - Fitting 5 folds for each of 9 candidates, totalling 45 fits
# - -6.0737250986537425
# - {'max_depth': 5, 'subsample': 0.9}

# %%
model_gbr_3 = GradientBoostingRegressor(n_estimators=600, learning_rate=0.01, max_depth=5, subsample=0.9, random_state=rs)

# %%
start = time.time()
model_gbr_3.fit(features_train, target_train)
time_learn = round((time.time() - start), 4)

# %%
cv_score(model_gbr_3, features_train, target_train)
# Out:
# Результат кросс валидации [-5.99319652 -5.85700358 -6.18144369 -5.81387187 -5.98980116]
# Результат средний -5.967

# %%
# %%time
prediction_train(model_gbr_3, features_train, target_train)
# Out:
# MAE на обучающей выборке 4.031
# Wall time: 31.3 ms

# %%
results_upd_train(model_number, model_name, time_learn, train_mae(model_gbr_3))
# Out:
#                             model  \
# 0               Linear Regression
# 1         Random Forest Regressor
# 2  Gradient Boosting Regregressor
#
#   time_learn, ms  \
# 0            0.0
# 1         1.4367
# 2         4.7289
#
#   time_predict, ms  \
# 0              NaN
# 1              NaN
# 2              NaN
#
#   mae_train  \
# 0  7.446701
# 1  4.352365
# 2  4.031257
#
#   mae_test
# 0      NaN
# 1      NaN
# 2      NaN

# %% [markdown]
# ### Cat Boost Regressor

# %%
model_number = 3
model_name = 'Cat Boost Regressor'

# %%
model_catboost = CatBoostRegressor(
                          iterations=2000, 
                          depth=8, 
                          learning_rate=0.02, 
                          loss_function='MAE', 
                          subsample=0.7,                     
                          verbose=0, 
                          random_seed=rs)

# %%
start = time.time()
model_catboost.fit(features_train, target_train)
time_learn = round((time.time() - start), 4)

# %%
# %%time
prediction_train(model_catboost, features_train, target_train)
# Out:
# MAE на обучающей выборке 1.953
# Wall time: 71 ms

# %%
cv_score(model_catboost, features_train, target_train)
# Out:
# Результат кросс валидации [-5.83340495 -5.90384482 -6.28760358 -6.02393225 -5.94327799]
# Результат средний -5.998

# %% [markdown]
# В итоге мы собрали следующую информацию о моделях:

# %%
results_upd_train(model_number, model_name, time_learn, train_mae(model_catboost))
# Out:
#                             model  \
# 0               Linear Regression
# 1         Random Forest Regressor
# 2  Gradient Boosting Regregressor
# 3               CatBoostRegressor
#
#   time_learn, ms  \
# 0            0.0
# 1         1.4367
# 2         4.7289
# 3        17.8144
#
#   time_predict, ms  \
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
#
#   mae_train  \
# 0  7.446701
# 1  4.352365
# 2  4.031257
# 3  1.953135
#
#   mae_test
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN

# %% [markdown]
# CatBoostRegressor вроде бы выглядит хорошо, но это может быть переобучением, и это мы увидим на тесте моделей.

# %% [markdown]
# ## Тестирование моделей

# %% [markdown]
# ### Linear Regression

# %%
model_number = 0

# %%
start = time.time()
prediction_test(model_lr, features_test, target_test)
time_learn = round((time.time() - start), 4)
# Out:
# MAE на тестовой выборке 7.683

# %%
results_upd_test(model_number, time_learn, test_mae(model_lr))
# Out:
#                             model  \
# 0               Linear Regression
# 1         Random Forest Regressor
# 2  Gradient Boosting Regregressor
# 3               CatBoostRegressor
#
#   time_learn, ms  \
# 0            0.0
# 1         1.4367
# 2         4.7289
# 3        17.8144
#
#   time_predict, ms  \
# 0            0.005
# 1              NaN
# 2              NaN
# 3              NaN
#
#   mae_train  \
# 0  7.446701
# 1  4.352365
# 2  4.031257
# 3  1.953135
#
#    mae_test
# 0  7.683383
# 1       NaN
# 2       NaN
# 3       NaN

# %% [markdown]
# ### Random Forest Regressor

# %%
model_number = 1

# %%
start = time.time()
prediction_test(model_rfr, features_test, target_test)
time_learn = round((time.time() - start), 4)
# Out:
# MAE на тестовой выборке 6.199

# %%
results_upd_test(model_number, time_learn, test_mae(model_rfr))
# Out:
#                             model  \
# 0               Linear Regression
# 1         Random Forest Regressor
# 2  Gradient Boosting Regregressor
# 3               CatBoostRegressor
#
#   time_learn, ms  \
# 0            0.0
# 1         1.4367
# 2         4.7289
# 3        17.8144
#
#   time_predict, ms  \
# 0            0.005
# 1            0.073
# 2              NaN
# 3              NaN
#
#   mae_train  \
# 0  7.446701
# 1  4.352365
# 2  4.031257
# 3  1.953135
#
#    mae_test
# 0  7.683383
# 1  6.198599
# 2       NaN
# 3       NaN

# %% [markdown]
# ### Gradient Boosting Regregressor

# %%
model_number = 2

# %%
start = time.time()
prediction_test(model_gbr_3, features_test, target_test)
time_learn = round((time.time() - start), 4)
# Out:
# MAE на тестовой выборке 5.911

# %%
results_upd_test(model_number, time_learn, test_mae(model_gbr_3))
# Out:
#                             model  \
# 0               Linear Regression
# 1         Random Forest Regressor
# 2  Gradient Boosting Regregressor
# 3               CatBoostRegressor
#
#   time_learn, ms  \
# 0            0.0
# 1         1.4367
# 2         4.7289
# 3        17.8144
#
#   time_predict, ms  \
# 0            0.005
# 1            0.073
# 2            0.014
# 3              NaN
#
#   mae_train  \
# 0  7.446701
# 1  4.352365
# 2  4.031257
# 3  1.953135
#
#    mae_test
# 0  7.683383
# 1  6.198599
# 2   5.91066
# 3       NaN

# %%
feat_importances = pd.Series(model_gbr_3.feature_importances_, index=features_train.columns)

plt.figure(figsize=(8,5))
feat_importances.nlargest(20).plot(kind='barh', color='gray')

plt.title('Важность признаков', size=18, y=1.02);

# %% [markdown]
# ### Cat Boost Regressor

# %%
model_number = 3

# %%
start = time.time()
prediction_test(model_catboost, features_test, target_test)
time_learn = round((time.time() - start), 4)
# Out:
# MAE на тестовой выборке 5.826

# %%
results_upd_test(model_number, time_learn, test_mae(model_catboost))
# Out:
#                             model  \
# 0               Linear Regression
# 1         Random Forest Regressor
# 2  Gradient Boosting Regregressor
# 3               CatBoostRegressor
#
#   time_learn, ms  \
# 0            0.0
# 1         1.4367
# 2         4.7289
# 3        17.8144
#
#   time_predict, ms  \
# 0            0.005
# 1            0.073
# 2            0.014
# 3              0.0
#
#   mae_train  \
# 0  7.446701
# 1  4.352365
# 2  4.031257
# 3  1.953135
#
#    mae_test
# 0  7.683383
# 1  6.198599
# 2   5.91066
# 3  5.825514

# %% [markdown]
# ### Сравнение моделей

# %%
results_final = result_data.copy()

results_final = results_final.\
                    style.\
                    applymap(color_text, subset='mae_test').\
                    apply(highlight_background, subset='mae_test')

results_final
# Out:
# <style type="text/css">
# #T_e2180_row0_col4, #T_e2180_row1_col4 {
#   color: white;
#   background-color: goldenrod;
# }
# #T_e2180_row2_col4, #T_e2180_row3_col4 {
#   color: white;
#   background-color: green;
# }
# </style>
# <table id="T_e2180_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >model</th>
#       <th class="col_heading level0 col1" >time_learn, ms</th>
#       <th class="col_heading level0 col2" >time_predict, ms</th>
#       <th class="col_heading level0 col3" >mae_train</th>
#       <th class="col_heading level0 col4" >mae_test</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2180_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2180_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_e2180_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_e2180_row0_col2" class="data row0 col2" >0.005000</td>
# ...

# %% [markdown]
# Построим график по MAE:

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax.vlines(x=result_data['model'], ymin=0, ymax=result_data['mae_test'], color='dimgrey', alpha=0.7, linewidth=2)
ax.scatter(x=result_data['model'], y=result_data['mae_test'], s=75, color='firebrick', alpha=0.85)


for row in result_data.itertuples():
    ax.text(row.model, row.mae_test+0.2, s=row.mae_test,
            horizontalalignment= 'center', verticalalignment='bottom', fontsize=12)


ax.set_title('МАЕ на тестовой выборке по моделям:', size=16, y=(1.02))
ax.set_ylabel('mae test')
ax.set_ylim(0,8)
ax.set_xticks(result_data['model'])
ax.set_xticklabels(result_data['model'], rotation=0, fontdict={'horizontalalignment': 'center', 'size':10})


plt.show()

# %% [markdown]
# ### Время предсказания на тестовой выборке:

# %%
result_data = result_data.rename(columns={'time_predict, ms':'time_predict'})

fig, ax = plt.subplots(figsize=(8,6))

ax.vlines(x=result_data['model'], ymin=0, ymax=result_data['time_predict'], color='dimgrey', alpha=0.8, linewidth=20)


for row in result_data.itertuples():
    ax.text(row.model, row.time_predict+0.2, s=row.time_predict,
            horizontalalignment= 'center', verticalalignment='bottom', fontsize=13)


ax.set_title('Сравнение времени предсказания на тестовой выборке', size=18, y=(1.04))
ax.set_ylabel('время, мсек')
ax.set_ylim(0,0.5)
ax.set_xticks(result_data['model'])
ax.set_xticklabels(result_data['model'], rotation=0, fontdict={'horizontalalignment': 'center', 'size':10})


plt.show()
