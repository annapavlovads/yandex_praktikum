# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Условия-задачи,-справка-и-план-исследования" data-toc-modified-id="Условия-задачи,-справка-и-план-исследования-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Условия задачи, справка и план исследования</a></span><ul class="toc-item"><li><span><a href="#Условия-задачи" data-toc-modified-id="Условия-задачи-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Условия задачи</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#План-исследования" data-toc-modified-id="План-исследования-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>План исследования</a></span></li><li><span><a href="#Целевые-метрики" data-toc-modified-id="Целевые-метрики-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Целевые метрики</a></span></li><li><span><a href="#Используемые-библиотеки" data-toc-modified-id="Используемые-библиотеки-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Используемые библиотеки</a></span></li><li><span><a href="#Используемые-функции" data-toc-modified-id="Используемые-функции-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Используемые функции</a></span></li></ul></li><li><span><a href="#Загрузка,-изучение-и-первичная-обработка-данных" data-toc-modified-id="Загрузка,-изучение-и-первичная-обработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузка, изучение и первичная обработка данных</a></span><ul class="toc-item"><li><span><a href="#Информация-о-договоре" data-toc-modified-id="Информация-о-договоре-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Информация о договоре</a></span><ul class="toc-item"><li><span><a href="#Общие-и-ежемесячные-расходы-клиентов." data-toc-modified-id="Общие-и-ежемесячные-расходы-клиентов.-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Общие и ежемесячные расходы клиентов.</a></span></li><li><span><a href="#Зависимость-TotalCharges-и-MonthlyCharges-от-lifetime-в-днях-и-друг-от-друга" data-toc-modified-id="Зависимость-TotalCharges-и-MonthlyCharges-от-lifetime-в-днях-и-друг-от-друга-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Зависимость TotalCharges и MonthlyCharges от lifetime в днях и друг от друга</a></span></li><li><span><a href="#Распределение-расходов-в-зависимости-от-других-данных-о-клиенте" data-toc-modified-id="Распределение-расходов-в-зависимости-от-других-данных-о-клиенте-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Распределение расходов в зависимости от других данных о клиенте</a></span></li><li><span><a href="#Когорты" data-toc-modified-id="Когорты-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Когорты</a></span></li></ul></li><li><span><a href="#Персональные-данные-клиента" data-toc-modified-id="Персональные-данные-клиента-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Персональные данные клиента</a></span><ul class="toc-item"><li><span><a href="#Общие-и-ежемесячные-расходы-клиентов" data-toc-modified-id="Общие-и-ежемесячные-расходы-клиентов-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Общие и ежемесячные расходы клиентов</a></span></li></ul></li><li><span><a href="#Информация-об-интернет-услугах" data-toc-modified-id="Информация-об-интернет-услугах-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Информация об интернет-услугах</a></span></li><li><span><a href="#Информация-об-услугах-телефонии" data-toc-modified-id="Информация-об-услугах-телефонии-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Информация об услугах телефонии</a></span></li><li><span><a href="#Исследовательский-анализ-сборных-данных" data-toc-modified-id="Исследовательский-анализ-сборных-данных-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Исследовательский анализ сборных данных</a></span><ul class="toc-item"><li><span><a href="#LabelEncoding" data-toc-modified-id="LabelEncoding-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>LabelEncoding</a></span></li><li><span><a href="#Корреляция" data-toc-modified-id="Корреляция-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Корреляция</a></span></li><li><span><a href="#Проверка-гипотез-о-влиянии-факторов-на-целевой-признак" data-toc-modified-id="Проверка-гипотез-о-влиянии-факторов-на-целевой-признак-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Проверка гипотез о влиянии факторов на целевой признак</a></span></li><li><span><a href="#Удаление-ненужных-признаков-для-ML" data-toc-modified-id="Удаление-ненужных-признаков-для-ML-2.5.4"><span class="toc-item-num">2.5.4&nbsp;&nbsp;</span>Удаление ненужных признаков для ML</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-2.5.5"><span class="toc-item-num">2.5.5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li></ul></li><li><span><a href="#План-работы,-направленный-тим-лиду:" data-toc-modified-id="План-работы,-направленный-тим-лиду:-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>План работы, направленный тим-лиду:</a></span></li><li><span><a href="#Список-уточняющих-вопросов-для-тим-лида" data-toc-modified-id="Список-уточняющих-вопросов-для-тим-лида-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Список уточняющих вопросов для тим-лида</a></span></li><li><span><a href="#Построение-моделей-машинного-обучения" data-toc-modified-id="Построение-моделей-машинного-обучения-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Построение моделей машинного обучения</a></span><ul class="toc-item"><li><span><a href="#LogisticRegression" data-toc-modified-id="LogisticRegression-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>LogisticRegression</a></span></li><li><span><a href="#RandomForestClassifier" data-toc-modified-id="RandomForestClassifier-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>RandomForestClassifier</a></span></li><li><span><a href="#LGBMClassifier" data-toc-modified-id="LGBMClassifier-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>LGBMClassifier</a></span></li></ul></li><li><span><a href="#Оценка-метрик-моделей" data-toc-modified-id="Оценка-метрик-моделей-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Оценка метрик моделей</a></span><ul class="toc-item"><li><span><a href="#ROC-AUC-кривая" data-toc-modified-id="ROC-AUC-кривая-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>ROC-AUC кривая</a></span></li><li><span><a href="#Матрица-ошибок" data-toc-modified-id="Матрица-ошибок-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Матрица ошибок</a></span></li><li><span><a href="#Важность-признаков" data-toc-modified-id="Важность-признаков-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Важность признаков</a></span></li><li><span><a href="#Альтернативная-модель-LGBMClassifier-на-части-данных" data-toc-modified-id="Альтернативная-модель-LGBMClassifier-на-части-данных-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Альтернативная модель LGBMClassifier на части данных</a></span></li></ul></li><li><span><a href="#Отчет-по-проекту" data-toc-modified-id="Отчет-по-проекту-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Отчет по проекту</a></span></li></ul></div>

# %% [markdown]
# ## Условия задачи, справка и план исследования

# %% [markdown]
# ### Условия задачи

# %% [markdown]
# Оператор связи хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.

# %% [markdown]
# Оператор предоставляет два основных типа услуг:
#
# 1. Стационарную телефонную связь. Возможно подключение телефонного аппарата к нескольким линиям одновременно.
# 2. Интернет. Подключение может быть двух типов: через телефонную линию (DSL*,* от англ. *digital subscriber line*, «цифровая абонентская линия») или оптоволоконный кабель (*Fiber optic*).
#
# Также доступны такие услуги:
#
# - Интернет-безопасность: антивирус (*DeviceProtection*) и блокировка небезопасных сайтов (*OnlineSecurity*);
# - Выделенная линия технической поддержки (*TechSupport*);
# - Облачное хранилище файлов для резервного копирования данных (*OnlineBackup*);
# - Стриминговое телевидение (*StreamingTV*) и каталог фильмов (*StreamingMovies*).
#
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года. Доступны различные способы расчёта и возможность получения электронного чека.

# %% [markdown]
# ### Описание данных

# %% [markdown]
# Данные состоят из файлов, полученных из разных источников:
#
# - `contract.csv` — информация о договоре;
# - `personal.csv` — персональные данные клиента;
# - `internet.csv` — информация об интернет-услугах;
# - `phone.csv` — информация об услугах телефонии.
#
# ! столбец `customerID` содержит код клиента.

# %% [markdown]
# ### План исследования

# %% [markdown]
# - Загрузить и рассмотреть данные в первом приближении.
# - Подготовить данные: в случае необходимости изменить типы данных; исследовать наличие и заполнить пропуски.
# - Задать появившиеся вопросы по данным Тим-лиду, скорректировать план в соответствии с полученными ответами.
# - Подготовить признаки. Составить единую таблицу со всеми данными для модели. Выделить и разделить на features и target.
# - Выбрать модели, построить и обучить модели классификации.
# - Оценить эффективности моделей на тестовой выборке.
# - Сделать выводы.

# %% [markdown]
# ### Целевые метрики

# %% [markdown]
# AUC-ROC ≥ 0.88

# %% [markdown]
# ### Используемые библиотеки

# %% [markdown]
# __Константы__

# %%
current_state = 116
current_date = '2020-02-01'
alpha = 0.05

# %% [markdown]
# __Библиотеки__

# %%
import pandas as pd
import numpy as np

import time
import datetime 
from datetime import datetime, date

# data viz
import seaborn as sns
sns.set(style='whitegrid')
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas.plotting import scatter_matrix

# import random
# import math

# statisctics 
# import statsmodels.api as sm
# from scipy import stats
from scipy.stats import chi2_contingency
# from scipy.stats import boxcox

# best parameters search
# import optuna
from sklearn.model_selection import GridSearchCV 
from sklearn.model_selection import RandomizedSearchCV
# from sklearn.model_selection import KFold, StratifiedKFold
# from sklearn.feature_selection import RFE
# from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_validate, cross_val_score, GridSearchCV

# #machine learning models
from sklearn.ensemble import IsolationForest
# # from sklearn.linear_model import RidgeCV
# from sklearn.linear_model import LinearRegression  
# # from sklearn.linear_model import Lasso
# # from sklearn.linear_model import Ridge
# #from sklearn.tree import DecisionTreeRegressor
# from sklearn.ensemble import RandomForestRegressor
# #from sklearn.neural_network import MLPRegressor 
#from lightgbm import LGBMRegressor
from lightgbm import LGBMClassifier
# from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier


# #dummy
# from sklearn.dummy import DummyRegressor
from sklearn.dummy import DummyClassifier

# import xgboost
# import catboost
# from catboost import Pool, CatBoostRegressor, CatBoostClassifier, cv

# ML instruments
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# from sklearn.preprocessing import MinMaxScaler



# encoders
from sklearn.preprocessing import LabelEncoder
# from sklearn.preprocessing import OrdinalEncoder
# from sklearn.preprocessing import OneHotEncoder
# from sklearn.preprocessing import Normalizer
# from sklearn.preprocessing import Binarizer
# #import category_encoders as ce

# # sklearn instruments
# from sklearn.utils import shuffle
# from sklearn.pipeline import Pipeline

# feature engineering
# from pandas.api.types import is_categorical_dtype
# from sklearn.cluster import KMeans
# from sklearn.decomposition import PCA

# metrics
# from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.metrics import roc_auc_score, precision_recall_curve, roc_curve
from sklearn.model_selection import cross_val_score
# from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, make_scorer

#dataset settings
pd.set_option('display.max_columns', 40) #макс кол-во колонок в выводимых данных 
pd.set_option('display.max_rows', 20) #макс кол-во строк в выводимых данных
pd.set_option('display.width', 20) #макс кол-во символов в строке

#warnings and other settings
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.simplefilter('ignore')
pd.options.mode.chained_assignment = None

# %%
project_start_time = time.time()

# %% [markdown]
# ### Используемые функции

# %% [markdown]
# Функция с общей информацией о датасете:

# %%
def df_info(df):
    display(df.shape)
    display(df.head(5))
    display(df.info())
    display(df.describe())
    print('Дубликаты')
    print(df[df.duplicated(keep="first")].count())
    print()
    print('Пропуски')
    for col in df.columns:
        pct_missing = np.mean(df[col].isnull())
        print('{} - {}%'.format(col, round(pct_missing*100), sep=''))

# %% [markdown]
# Функция для преобразования даты:

# %%
def datetime(df, column):
    df[column] = pd.to_datetime(df[column], format='%Y-%m-%dT%H:%M:%S')

# %% [markdown]
# Функция для преобразования типа данных:

# %%
def to_numeric(df, column):
    df[column] = pd.to_numeric(df[column]).astype('float')

# %% [markdown]
# Функция для создания маркера "клиент перестал быть клиентом":

# %%
def gone_detector(item): 
    if item=='No': 
        return 0
    else: 
        return 1

# %% [markdown]
# Функция возврата 1, если мужской пол:

# %%
def is_male(item): 
    if item=='Male':
        return 1
    else: 
        return 0

# %% [markdown]
# Функция для матрицы корреляций:

# %%
def num_corr(df, cols=None, hue=None):
    if cols == None:
        cols = [col for col in df.columns if df[col].dtype in ['float64','int64']]
    
    corr = round(df[cols].corr(), 2)
    #display(corr)
    
    mask = np.zeros_like(corr)
    mask[np.triu_indices_from(mask)] = True
    f, ax = plt.subplots(figsize=(40, 20))
    ax = sns.heatmap(corr, mask=mask, center=0, vmax=1, vmin=-1, square=True, annot=True, cmap='YlGnBu')
    plt.show()
    
    sns.pairplot(data=df, x_vars=cols, y_vars=cols, corner=True, diag_kind='kde', hue=hue)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Функция проверки гипотез (хи-квадратом):

# %%
def check_with_chi2(col_group):
    table1 = merged.groupby(col_group, as_index=False)['is_gone'].sum()
    table2 = merged.groupby(col_group, as_index=False)['customerID'].count()
    merged_1 = table1.merge(table2, on=col_group)
    merged_1.rename(columns = {'customerID':'all'}, inplace = True)
    merged_1['not_gone'] = merged_1['all'] - merged_1['is_gone']
    merged_1 = merged_1.drop('all', axis=1)
        
    stat, p, dof, expected = chi2_contingency(merged_1[['is_gone', 'not_gone']])
      
    return merged_1, p

# %% [markdown]
# Таблица и функция обновления таблицы с итоговыми данными моделей:

# %%
result_data = pd.DataFrame(
    columns=['model_name','time_learn','time_predict', 'ROC_AUC_test', 'accuracy_test']
)
result_data
# Out:
# Empty DataFrame
# Columns: [model_name, time_learn, time_predict, ROC_AUC_test, accuracy_test]
# Index: []

# %%
def results_upd(row, model_name, time_learn, time_predict, ROC_AUC_test, accuracy_test):
    
    result_data.loc[row, 'model_name'] = model_name
    result_data.loc[row, 'time_learn'] = time_learn
    result_data.loc[row, 'time_predict'] = time_predict
    result_data.loc[row, 'ROC_AUC_test'] = ROC_AUC_test
    result_data.loc[row, 'accuracy_test'] = accuracy_test
    
    display(result_data)

# %% [markdown]
# Функция, принимающая на вход модель, train и test features и target, выводящая интересующие нас метрики ROC-AUC, Accuracy, а также для справки и иные метрики:

# %%
def model_final(model, X_train, y_train, X_test, y_test):
    start = time.time()    
    model.fit(X_train, y_train)
    train_time = time.time() - start
    
    start = time.time()  
    y_pred = model.predict(X_test)
    predict_time = time.time() - start
    
    roc_auc = roc_auc_score(y_test, model.predict_proba(X_test)[:,1])
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)

    return train_time, predict_time, roc_auc, accuracy, precision, recall

# %% [markdown]
# ## Загрузка, изучение и первичная обработка данных

# %% [markdown]
# ### Информация о договоре

# %% [markdown]
# __contract.csv__ — информация о договоре

# %%
try: 
    contract = pd.read_csv('/datasets/final_provider/contract.csv')
    
except: 
    contract = pd.read_csv('datasets/final_provider/contract.csv')
    
df_info(contract)
# Out:
# (7043, 8)
#    customerID  \
# 0  7590-VHVEG
# 1  5575-GNVDE
# 2  3668-QPYBK
# 3  7795-CFOCW
# 4  9237-HQITU
#
#     BeginDate  \
# 0  2020-01-01
# 1  2017-04-01
# 2  2019-10-01
# 3  2016-05-01
# 4  2019-09-01
#
#                EndDate  \
# 0                   No
# 1                   No
# 2  2019-12-01 00:00:00
# 3                   No
# 4  2019-11-01 00:00:00
#
#              Type  \
# 0  Month-to-month
# 1        One year
# 2  Month-to-month
# 3        One year
# 4  Month-to-month
#
#   PaperlessBilling  \
# 0              Yes
# 1               No
# 2              Yes
# 3               No
# 4              Yes
#
#                PaymentMethod  \
# 0           Electronic check
# 1               Mailed check
# 2               Mailed check
# 3  Bank transfer (automatic)
# 4           Electronic check
#
#    MonthlyCharges  \
# 0           29.85
# 1           56.95
# 2           53.85
# 3           42.30
# 4           70.70
#
#   TotalCharges
# 0        29.85
# 1       1889.5
# ...

# %%
contract.shape[0]-contract.customerID.nunique()
# Out:
# 0

# %% [markdown]
# Дублирований customerID нет. Посмотрим, какие еще есть данные.

# %%
contract['PaperlessBilling'].value_counts()
# Out:
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64

# %% [markdown]
# Счет за услуги либо бумажный, либо нет.

# %%
contract['Type'].value_counts()
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Type, dtype: int64

# %% [markdown]
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года, это и есть данные о типе договора.

# %% [markdown]
# Способоы оплаты:

# %%
contract['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %% [markdown]
# Даты требуют приведения к формату даты, пропусков и дубликатов не обнаружено.

# %%
datetime(contract, 'BeginDate')

# %%
print(contract['BeginDate'].min(), contract['BeginDate'].max())
# Out:
# 2013-10-01 00:00:00 2020-02-01 00:00:00

# %% [markdown]
# Самый старый клиент у нас уже почти 7 лет: с 1 октября 2013 года. Самый новый клиент присоединился в день выгрузки данных для исследования.

# %% [markdown]
# В столбце 'TotalCharges' неверный тип данных. Пропусков, на первый взгляд, не видно, но числа не распознались как числа, возможно, среди них затесался текст, который помешает изменить формат данных.

# %%
contract['TotalCharges'].value_counts()
# Out:
#           11
# 20.2      11
# 19.75      9
# 20.05      8
# 19.9       8
#           ..
# 6849.4     1
# 692.35     1
# 130.15     1
# 3211.9     1
# 6844.5     1
# Name: TotalCharges, Length: 6531, dtype: int64

# %% [markdown]
# Видим проблему: 11 пробелов. Очевидно, TotalCharges должны быть равны MonthlyCharges, умноженному на количество месяцев, которые абонент был абонентом. Посмотрим, так ли это. И если да, заполним пропуски.

# %%
display(contract.loc[contract['TotalCharges']==' '].shape)
contract.loc[contract['TotalCharges']==' ']
# Out:
# (11, 8)
#       customerID  \
# 488   4472-LVYGI
# 753   3115-CZMZD
# 936   5709-LVOEQ
# 1082  4367-NUYAO
# 1340  1371-DWPAZ
# 3331  7644-OMVMY
# 3826  3213-VVOLG
# 4380  2520-SGTTA
# 5218  2923-ARZLG
# 6670  4075-WKNIU
# 6754  2775-SEFEE
#
#       BeginDate  \
# 488  2020-02-01
# 753  2020-02-01
# 936  2020-02-01
# 1082 2020-02-01
# 1340 2020-02-01
# 3331 2020-02-01
# 3826 2020-02-01
# 4380 2020-02-01
# 5218 2020-02-01
# 6670 2020-02-01
# 6754 2020-02-01
#
#      EndDate  \
# 488       No
# 753       No
# 936       No
# 1082      No
# 1340      No
# 3331      No
# 3826      No
# 4380      No
# 5218      No
# 6670      No
# 6754      No
#
#           Type  \
# 488   Two year
# 753   Two year
# 936   Two year
# 1082  Two year
# 1340  Two year
# 3331  Two year
# 3826  Two year
# 4380  Two year
# 5218  One year
# 6670  Two year
# 6754  Two year
#
#      PaperlessBilling  \
# 488               Yes
# 753                No
# 936                No
# 1082               No
# ...

# %%
contract.loc[contract['EndDate']!='No']
# Out:
#       customerID  \
# 2     3668-QPYBK
# 4     9237-HQITU
# 5     9305-CDSKC
# 8     7892-POOKP
# 13    0280-XJGEX
# ...          ...
# 7021  1699-HPSBG
# 7026  8775-CEBBJ
# 7032  6894-LFHLY
# 7034  0639-TSIQW
# 7041  8361-LTMKD
#
#       BeginDate  \
# 2    2019-10-01
# 4    2019-09-01
# 5    2019-03-01
# 8    2017-07-01
# 13   2015-09-01
# ...         ...
# 7021 2018-11-01
# 7026 2019-02-01
# 7032 2019-10-01
# 7034 2014-03-01
# 7041 2019-07-01
#
#                   EndDate  \
# 2     2019-12-01 00:00:00
# 4     2019-11-01 00:00:00
# 5     2019-11-01 00:00:00
# 8     2019-11-01 00:00:00
# 13    2019-10-01 00:00:00
# ...                   ...
# 7021  2019-11-01 00:00:00
# 7026  2019-11-01 00:00:00
# 7032  2019-11-01 00:00:00
# 7034  2019-10-01 00:00:00
# 7041  2019-11-01 00:00:00
#
#                 Type  \
# 2     Month-to-month
# 4     Month-to-month
# 5     Month-to-month
# 8     Month-to-month
# 13    Month-to-month
# ...              ...
# 7021        One year
# ...

# %% [markdown]
# Кстати, видим, что 1869 клиентов - абоненты, покинувшие компанию. Это говорит о дисбалансе классов целевого признака для моделей машинного обучения. А также о том, что, возможно, компании есть что изменить к лучшему, чтобы предотвратить отток. Хотя неизвестно, какой уровень ухода клиентов считается "нормальным" на рынке данных услуг. Вот столько процентов клиентов из всего пула за это время покинули компанию:

# %%
round(((contract.loc[contract['EndDate']!='No'].shape[0] / contract.shape[0]) *100), 2)
# Out:
# 26.54

# %% [markdown]
# Взглянув на пример данных выше, видим, что действительно TotalCharges практически равняется количеству месяцев, которые клиент был клиентом, умноженному на MonthlyCharges.

# %%
contract['current_date'] = contract['EndDate']

# %%
contract.loc[contract['EndDate']=='No', 'current_date'] = current_date

# %%
datetime(contract, 'current_date')

# %%
contract['lifetime_days'] = (contract['current_date'] - contract['BeginDate']).dt.days

# %% [markdown]
# Подсчитаем и округлим количество месяцев, которое клиент провел с компанией для расчета TotalCharges.

# %%
contract['month_qty'] = (contract['lifetime_days'] / 30).astype('int')

# %% [markdown]
# Присвоим маркер целевого признака (покинул / не покинул компанию)

# %%
contract['is_gone'] = contract['EndDate'].apply(gone_detector)

# %%
contract.loc[contract['TotalCharges']==' ', 'TotalCharges'] = contract.loc[contract['TotalCharges']==' ']['MonthlyCharges'] * contract.loc[contract['TotalCharges']==' ']['month_qty']

# %%
to_numeric(contract, 'TotalCharges')

# %% [markdown]
# __Посмотрим на распределение lifetime_days у ушедших клиентов__

# %%
gone_lifetime=contract.loc[contract['is_gone']==1]['lifetime_days']

# %%
gone_lifetime.describe()
# Out:
# count    1869.000000
# mean      547.352060
# std       594.389607
# min        30.000000
# 25%        61.000000
# 50%       304.000000
# 75%       883.000000
# max      2191.000000
# Name: lifetime_days, dtype: float64

# %%
plt.figure(figsize=(10,20))
plt.boxplot([gone_lifetime])
plt.title('Распределение lifetime_days у ушедших клиентов')
plt.xlabel(' ')
plt.ylabel('lifetime_days')
plt.xticks()
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.distplot(gone_lifetime, color='dimgrey')
plt.xlabel('дней', size=12)
plt.ylabel('Плотность вероятности', size=12)
plt.title('Распределение жизненного срока (lifetime_days) у ушедших клиентов', size=16);

# %% [markdown]
# Половина клиентов не проводят с компанией и года. Распределение смещено в сторону малых значений. Есть только несколько выбросов: клиенты, которые были с компанией долго, а потом ушли.

# %% [markdown]
# #### Общие и ежемесячные расходы клиентов.

# %% [markdown]
# Посмотрим на распределение данных в числовых столбцах MonthlyCharges, TotalCharges.

# %%
contract['TotalCharges'].describe()
# Out:
# count    7043.000000
# mean     2279.734304
# std      2266.794470
# min         0.000000
# 25%       398.550000
# 50%      1394.550000
# 75%      3786.600000
# max      8684.800000
# Name: TotalCharges, dtype: float64

# %% [markdown]
# Нулевые расходы у клиентов, которые только что подключились:

# %%
contract.loc[contract['TotalCharges']==0].head()
# Out:
#       customerID  \
# 488   4472-LVYGI
# 753   3115-CZMZD
# 936   5709-LVOEQ
# 1082  4367-NUYAO
# 1340  1371-DWPAZ
#
#       BeginDate  \
# 488  2020-02-01
# 753  2020-02-01
# 936  2020-02-01
# 1082 2020-02-01
# 1340 2020-02-01
#
#      EndDate  \
# 488       No
# 753       No
# 936       No
# 1082      No
# 1340      No
#
#           Type  \
# 488   Two year
# 753   Two year
# 936   Two year
# 1082  Two year
# 1340  Two year
#
#      PaperlessBilling  \
# 488               Yes
# 753                No
# 936                No
# 1082               No
# 1340               No
#
#                   PaymentMethod  \
# 488   Bank transfer (automatic)
# 753                Mailed check
# 936                Mailed check
# 1082               Mailed check
# 1340    Credit card (automatic)
#
#       MonthlyCharges  \
# 488            52.55
# 753            20.25
# 936            80.85
# 1082           25.75
# 1340           56.05
#
#       TotalCharges  \
# 488            0.0
# ...

# %% [markdown]
# Видим, что среднее смещено в сторону от медианы, 25%-й квантиль в 20 раз меньше максимального значения. Посмотрим, как распределены данные у тех, кто ушел, и тех, кто остался.

# %%
left = contract.loc[contract['is_gone']==1]['TotalCharges']
stayed = contract.loc[contract['is_gone']==0]['TotalCharges']

# %%
print('Ушедшие клиенты:')
display(left.describe())
print('Оставшиеся клиенты:')
display(stayed.describe())
# Out:
# Ушедшие клиенты:
# count    1869.000000
# mean     1531.796094
# std      1890.822994
# min        18.850000
# 25%       134.500000
# 50%       703.550000
# 75%      2331.300000
# max      8684.800000
# Name: TotalCharges, dtype: float64
# Оставшиеся клиенты:
# count    5174.000000
# mean     2549.911442
# std      2329.954215
# min         0.000000
# 25%       572.900000
# 50%      1679.525000
# 75%      4262.850000
# max      8672.450000
# Name: TotalCharges, dtype: float64

# %%
plt.figure(figsize=(10,20))
plt.boxplot([left, stayed])
plt.title('Распределение TotalCharges по группам клиентов (ушел / остался)')
plt.xlabel(' ')
plt.ylabel('TotalCharges')
plt.xticks([1,2], ['Ушедшие клиенты','Оставшиеся клиенты'])
plt.show()

# %% [markdown]
# Видим, что у ушедших клиентов boxplot смещен к нулю по сравнению с оставшимися клиентами, а также большое количество выбросов (в рамках этого распределение). Хотя если посмотреть на границы данных из describe, видим, что максимум и минимум в данных, в общем, совпадают.

# %% [markdown]
# Возможно, ушедшие клиенты не более "дешевые", а те, кто пришел недавно, и еще не успел "накопить" значительные TotalCharges.

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.distplot(left, color='dimgrey')
plt.xlabel('TotalCharges', size=12)
plt.ylabel('Плотность вероятности', size=12)
plt.title('Распределение TotalCharges у ушедших клиентов', size=16);

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.distplot(stayed, color='dimgrey')
plt.xlabel('TotalCharges', size=12)
plt.ylabel('Плотность вероятности', size=12)
plt.title('Распределение TotalCharges у оставшихся клиентов', size=16);

# %% [markdown]
# Также можно будет проверить гипотезу о том, что ушедшие клиенты, в среднем, в месяц, тратят меньше, чем оставшиеся. Для этого сначала исследуем данные в MonthlyCharges.

# %%
contract['MonthlyCharges'].describe()
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %%
left = contract.loc[contract['is_gone']==1]['MonthlyCharges']
stayed = contract.loc[contract['is_gone']==0]['MonthlyCharges']
print('Ушедшие клиенты:')
display(left.describe())
print('Оставшиеся клиенты:')
display(stayed.describe())
# Out:
# Ушедшие клиенты:
# count    1869.000000
# mean       74.441332
# std        24.666053
# min        18.850000
# 25%        56.150000
# 50%        79.650000
# 75%        94.200000
# max       118.350000
# Name: MonthlyCharges, dtype: float64
# Оставшиеся клиенты:
# count    5174.000000
# mean       61.265124
# std        31.092648
# min        18.250000
# 25%        25.100000
# 50%        64.425000
# 75%        88.400000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# Медианное значение ежемесячных расходов (также, как и среднее), у ушедших клиентов выше. То, что компания теряет готовых использоваться услуги и платить клиентов, иллюстрирует и боксплот ниже:

# %%
plt.figure(figsize=(10,20))
plt.boxplot([left, stayed])
plt.title('Распределение MonthlyCharges по группам клиентов (ушел / остался)')
plt.xlabel(' ')
plt.ylabel('MonthlyCharges')
plt.xticks([1,2], ['Ушедшие клиенты','Оставшиеся клиенты'])
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.distplot(left, color='dimgrey')
plt.xlabel('MonthlyCharges', size=12)
plt.ylabel('Плотность вероятности', size=12)
plt.title('Распределение MonthlyCharges у ушедших клиентов', size=16);

# %% [markdown]
# Здесь мы видим несколько пиков в MonthlyCharges. Возможно, это стоимость тарифов.

# %%
contract.head(2)
# Out:
#    customerID  \
# 0  7590-VHVEG
# 1  5575-GNVDE
#
#    BeginDate  \
# 0 2020-01-01
# 1 2017-04-01
#
#   EndDate  \
# 0      No
# 1      No
#
#              Type  \
# 0  Month-to-month
# 1        One year
#
#   PaperlessBilling  \
# 0              Yes
# 1               No
#
#       PaymentMethod  \
# 0  Electronic check
# 1      Mailed check
#
#    MonthlyCharges  \
# 0           29.85
# 1           56.95
#
#    TotalCharges  \
# 0         29.85
# 1       1889.50
#
#   current_date  \
# 0   2020-02-01
# 1   2020-02-01
#
#    lifetime_days  \
# 0             31
# 1           1036
#
#    month_qty  \
# 0          1
# 1         34
#
#    is_gone
# 0        0
# 1        0

# %%
contract.loc[contract['is_gone']==1].groupby('Type')['MonthlyCharges'].median()
# Out:
# Type
# Month-to-month    79.050
# One year          95.050
# Two year          97.275
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# Если мы сгруппируем ушедших клиентов по типу контракта и посмотрим на их средние ежемесячные расходы, то увидим, что наиболее платежеспособные клиенты обладали тарифом Two year, One year - их потеря наиболее невыгодна. Хотя здесь, конечно, мы видим только абсолютную цену тарифа для клиента, и информации о том, насколько выгоден тот или иной клиентский тариф для компании, у нас нет (нет данных о затратах): поэтому будем считать, что чем больше денег приносит клиент, тем он ценнее, независимо от содержания и себестоимости услуг, которыми он пользуется.

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(12,6))
sns.distplot(stayed, color='dimgrey')
plt.xlabel('MonthlyCharges', size=12)
plt.ylabel('Плотность вероятности', size=12)
plt.title('Распределение MonthlyCharges у оставшихся клиентов', size=16);

# %% [markdown]
# В ежемесячных расходах оставшихся клиентов картина иная: средние расходы ушедших клиентов (квантили 25-75%) распределены более компактно и медиана смещена выше по отношению к оставшимся. Распределение показывает, что чаще всего оставшиеся клиенты используют некий минимальный тариф, других явно выраженных мод нет. То, что оставшиеся клиенты платят меньше, показывает и сводная таблица ниже:

# %%
contract.loc[contract['is_gone']==0].groupby('Type')['MonthlyCharges'].median()
# Out:
# Type
# Month-to-month    64.95
# One year          64.85
# Two year          63.30
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# #### Зависимость TotalCharges и MonthlyCharges от lifetime в днях и друг от друга

# %% [markdown]
# __TotalCharges__

# %%
contract.TotalCharges.corr(contract.lifetime_days)
# Out:
# 0.8261089182199315

# %%
sns.scatterplot(data=contract, x="lifetime_days", y="TotalCharges", color='dimgrey')
plt.title('Зависимость общих расходов от lifetime')
plt.show()

# %% [markdown]
# Видим существенную прямую зависимость, что также видно на графике. Это логично: более "долго живущие" клиенты накопили бОльшие расходы за это время. Это также означает, что один из этих столбцов должен быть исключен из сборного датасета, который мы будем использовать для моделей машинного обучения.

# %%
contract.loc[contract['is_gone']==1].TotalCharges.corr(contract.loc[contract['is_gone']==1].lifetime_days)
# Out:
# 0.9540273457043802

# %%
contract.loc[contract['is_gone']==0].TotalCharges.corr(contract.loc[contract['is_gone']==0].lifetime_days)
# Out:
# 0.7937141358758447

# %% [markdown]
# При этом если мы посмотрим, в каких группах (ушел-остался) эта зависимость сильнее, то это ушедшие клиенты. Это подтверждает предыдущие выводы.

# %% [markdown]
# __MonthlyCharges__

# %%
contract.MonthlyCharges.corr(contract.lifetime_days)
# Out:
# 0.2477539839011494

# %%
sns.scatterplot(data=contract, x="lifetime_days", y="MonthlyCharges", color='dimgrey')
plt.title('Зависимость средних расходов в месяц от lifetime')
plt.show()

# %%
contract.loc[contract['is_gone']==1].MonthlyCharges.corr(contract.loc[contract['is_gone']==1].lifetime_days)
# Out:
# 0.4013309360438749

# %%
contract.loc[contract['is_gone']==0].MonthlyCharges.corr(contract.loc[contract['is_gone']==0].lifetime_days)
# Out:
# 0.33087800317344834

# %% [markdown]
# Зависимость MonthlyCharges от длины "жизни" клиента в компании несущественная, однако и тут она у ушедших клиентов выше, чем у оставшихся.

# %% [markdown]
# __Друг от друга__

# %%
contract.TotalCharges.corr(contract.MonthlyCharges)
# Out:
# 0.6511738315787841

# %%
sns.scatterplot(data=contract, x="MonthlyCharges", y="TotalCharges", color='dimgrey')
plt.title('Взаимосвязь общих расходов и средних за месяц')
plt.show()

# %% [markdown]
# Видим прямую средней силы зависимость общих платежей клиента от ежемесячных.

# %%
contract.loc[contract['is_gone']==1].MonthlyCharges.corr(contract.loc[contract['is_gone']==1].TotalCharges)
# Out:
# 0.545772437945678

# %%
contract.loc[contract['is_gone']==0].MonthlyCharges.corr(contract.loc[contract['is_gone']==0].TotalCharges)
# Out:
# 0.7568737425379171

# %% [markdown]
# Эта зависимость у ушедших клиентов существеннее, чем у оставшихся.

# %% [markdown]
# __Вывод:__

# %% [markdown]
# - очевидно, что компания теряет готовых платить клиентов
# - потери клиентов, по имеющимся у нас данным, более четверти от клиентской базы

# %% [markdown]
# #### Распределение расходов в зависимости от других данных о клиенте

# %% [markdown]
# Посмотрим на распределение данных об общих расходах клиента по столбцам Type, PaymentMethod, PaperlessBilling.

# %% [markdown]
# __TotalCharges__

# %%
for i, col in enumerate(['Type','PaymentMethod','PaperlessBilling']): 
    plt.figure(i)
    sns.catplot(x=col, y='TotalCharges', data=contract, kind='point', color='dimgrey', aspect=2,)

# %% [markdown]
# Type - это виды тарифов (по частоте оплаты) - тариф оплаты за каждый месяц, за год и за два, и видно, что клиенты ежемесячного тарифа осуществили меньше всего суммарных платежей.

# %% [markdown]
# Здесь же посмотрим на распределение ушедших клиентов по виду их тарифа. Оставим пайчарты цветными.

# %%
plt.figure(figsize=(10,7))
plt.pie(contract.loc[contract['is_gone']==1].groupby('Type')['customerID'].count(),autopct='%1.1f%%')
plt.title('Доля различных видов тарифа у ушедших клиентов')
plt.legend(contract.loc[contract['is_gone']==1].groupby('Type')['customerID'].count().index)
plt.show()

# %% [markdown]
# Здесь же посмотрим, как распределены доли клиентов по видам тарифа вообще у всех клиентов:

# %%
plt.figure(figsize=(10,7))
plt.pie(contract.groupby('Type')['customerID'].count(),autopct='%1.1f%%')
plt.title('Доля различных видов тарифа у всех клиентов')
plt.legend(contract.groupby('Type')['customerID'].count().index)
plt.show()

# %% [markdown]
# Как видим, ежемесячных тарифов тут также больше, но не в такой пропорции, как у ушедших клиентов. Это логично: тот, кто платит каждый месяц, имеет большую свободу выбора в том, чтобы уйти или остаться: не нужно даже расторгать договор и возвращать оплату, сделанную на много месяц вперед.

# %% [markdown]
# В остальном, бумажный чек (отправляемый по почте) влияет на общие расходы, снижая их (возможно, это также означает, что клиент более возрастной или консервативный, узнаем из других датасетов с данными о клиентах)

# %% [markdown]
# __MonthlyCharges__

# %% [markdown]
# Посмотрим на распределение данных о ежемесячных расходах клиента по столбцам Type, PaymentMethod, PaperlessBilling.

# %%
for i, col in enumerate(['Type','PaymentMethod','PaperlessBilling']): 
    plt.figure(i)
    sns.catplot(x=col, y='MonthlyCharges', data=contract, kind='point', color='dimgrey', aspect=2,)

# %% [markdown]
# Ежемесячные расходы по категориям от month-to-month к более долгим тарифам снижаются. Они также много меньше при наличии бумажного чека.

# %% [markdown]
# #### Когорты

# %% [markdown]
# Добавим данные и посмотрим в первом приближении на когорты.

# %%
contract['month_came'] = contract['BeginDate'].dt.month
contract['year_came'] = contract['BeginDate'].dt.year

# %%
contract.groupby('year_came')['customerID'].count()
# Out:
# year_came
# 2013       8
# 2014    1344
# 2015     852
# 2016     763
# 2017     845
# 2018    1030
# 2019    1957
# 2020     244
# Name: customerID, dtype: int64

# %%
contract.groupby('year_came')['customerID'].count().plot(color='dimgrey')
# Out:
# <AxesSubplot:xlabel='year_came'>

# %% [markdown]
# Видим два пика появления клиентов: в 2014 и в 2019 году, между ними - провал с точкой минимума в 2016 г.

# %% [markdown]
# Если мы посмотрим на два графика ниже, то увидим, что ушедшие клиенты в более ранних годах регистрации - по количеству - более равномерны, чем оставшиеся, график которых повторяет график всех клиентов вместе.

# %% [markdown]
# Можно дополнительно проверить гипотезу, верно ли, что более "старые" клиенты более лояльны, меньше уходят.

# %%
contract.loc[contract['is_gone']==1].groupby('year_came')['customerID'].count().plot(color='dimgrey')
# Out:
# <AxesSubplot:xlabel='year_came'>

# %%
contract.loc[contract['is_gone']==0].groupby('year_came')['customerID'].count().plot(color='dimgrey')
# Out:
# <AxesSubplot:xlabel='year_came'>

# %% [markdown]
# Судя по данным о месяцах, больше всего клиенты приходят в феврале, в середине года затишье, затем прирост к концу года. Впрочем, возможно, эти данные искажены каким-то одним годом, поэтому если мы хотим подробно исследовать этот вопрос, следует разделить по годам.

# %%
contract.groupby('month_came')['customerID'].count().plot(color='dimgrey')
# Out:
# <AxesSubplot:xlabel='month_came'>

# %% [markdown]
# Сводная таблица по ушедшим клиентам:

# %%
left_customer = contract.loc[contract['EndDate']!='No']

# %%
datetime(left_customer, 'EndDate')

# %%
left_customer['month_gone'] = left_customer['EndDate'].dt.month
left_customer['year_gone'] = left_customer['EndDate'].dt.year

# %%
left_customer.groupby('year_gone')['customerID'].count()
# Out:
# year_gone
# 2019    1409
# 2020     460
# Name: customerID, dtype: int64

# %% [markdown]
# Почему есть данные о старых клиентах, но нет данных об уходе клиентов до 2019 г.? Клиенты вообще не уходили до 2019 г.?

# %%
left_customer.groupby('month_gone')['customerID'].count()
# Out:
# month_gone
# 1     460
# 10    458
# 11    485
# 12    466
# Name: customerID, dtype: int64

# %% [markdown]
# Клиенты уходили с января и в конце года, а в середине года? Либо в это время что-то происходит (новый тариф?) - либо у нас просто такие данные.

# %% [markdown]
# Посмотрим на гистограмму ухода клиентов в зависимости от года, когда они стали клиентами:

# %%
plt.figure(figsize=(12,8))
left_customer.loc[left_customer['is_gone'] == 1]['year_came'].plot(kind='hist', bins=50, grid=True, color='dimgrey')
plt.title('Гистограмма ушедших клиентов по году начала пользования услугами')
plt.xlabel('Год подключения')
plt.ylabel('Количество ушедших клиентов')
plt.show()

# %% [markdown]
# Вроде бы это выглядит так, что "старые" клиенты лояльнее, но в более ранние годы их и подключалось поменьше, чем в последнее время. К тому же все же есть вопрос о качестве данных в части даты, когда клиент перестал быть клиентом. Возможно, тогда просто провели собрали данные и провели опрос, поэтому все ранее ушедшие клиенты были "зафиксированы" этой датой (или истек срок старых тарифов, длившихся какое-то время).

# %% [markdown]
# Как мы вообще принимаем решение о том, что клиент "ушел"? Он перестал тратить / платить / расторг договор с оператором?

# %% [markdown]
# __Вывод__

# %% [markdown]
# - существенных пропусков, дубликатов и испорченных данных в первом приближении в датасете не обнаружено, переходим к следующим
# - компания теряет клиентов, в среднем, готовых к бОльшим тратам на услуги, чем оставшиеся

# %% [markdown]
# ### Персональные данные клиента

# %% [markdown]
# __personal.csv__ — персональные данные клиента

# %%
try: 
    personal = pd.read_csv('/datasets/final_provider/personal.csv')
    
except: 
    personal = pd.read_csv('datasets/final_provider/personal.csv')
    
df_info(personal)
# Out:
# (7043, 5)
#    customerID  \
# 0  7590-VHVEG
# 1  5575-GNVDE
# 2  3668-QPYBK
# 3  7795-CFOCW
# 4  9237-HQITU
#
#    gender  \
# 0  Female
# 1    Male
# 2    Male
# 3    Male
# 4  Female
#
#    SeniorCitizen  \
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
#
#   Partner  \
# 0     Yes
# 1      No
# 2      No
# 3      No
# 4      No
#
#   Dependents
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB
# None
#        SeniorCitizen
# ...

# %% [markdown]
# Дубликатов и пропусков в первом приближении не обнаружено.

# %%
contract.shape[0]-personal.shape[0]
# Out:
# 0

# %%
personal.shape[0] - personal['customerID'].nunique()
# Out:
# 0

# %% [markdown]
# Количество записей в датасетах personal, contract совпадает.

# %%
counter = 0
for id in list(contract['customerID']): 
    if id in list(personal['customerID']): 
        counter +=1
counter
# Out:
# 7043

# %% [markdown]
# Перечни customerID также совпадают.

# %% [markdown]
# Посмотрим, какие данные есть датасете:

# %%
display(personal['gender'].value_counts())
display(personal['SeniorCitizen'].value_counts())
display(personal['Partner'].value_counts())
display(personal['Dependents'].value_counts())
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64
# 0    5901
# 1    1142
# Name: SeniorCitizen, dtype: int64
# No     3641
# Yes    3402
# Name: Partner, dtype: int64
# No     4933
# Yes    2110
# Name: Dependents, dtype: int64

# %% [markdown]
# Распределение количества клиентов по полу, наличию партнера почти равное. Тех, у кого есть дети и пенсионеров, неравномерное.

# %% [markdown]
# Присоединим первый датасет ко второму и посмотрим, как мы можем посмотреть на эти данные в разрезе того, ушел клиент или остался.

# %%
merged = contract.merge(personal, how='left', on='customerID')

# %%
merged.shape
# Out:
# (7043, 18)

# %%
merged.head()
# Out:
#    customerID  \
# 0  7590-VHVEG
# 1  5575-GNVDE
# 2  3668-QPYBK
# 3  7795-CFOCW
# 4  9237-HQITU
#
#    BeginDate  \
# 0 2020-01-01
# 1 2017-04-01
# 2 2019-10-01
# 3 2016-05-01
# 4 2019-09-01
#
#                EndDate  \
# 0                   No
# 1                   No
# 2  2019-12-01 00:00:00
# 3                   No
# 4  2019-11-01 00:00:00
#
#              Type  \
# 0  Month-to-month
# 1        One year
# 2  Month-to-month
# 3        One year
# 4  Month-to-month
#
#   PaperlessBilling  \
# 0              Yes
# 1               No
# 2              Yes
# 3               No
# 4              Yes
#
#                PaymentMethod  \
# 0           Electronic check
# 1               Mailed check
# 2               Mailed check
# 3  Bank transfer (automatic)
# 4           Electronic check
#
#    MonthlyCharges  \
# 0           29.85
# 1           56.95
# 2           53.85
# 3           42.30
# 4           70.70
#
#    TotalCharges  \
# 0         29.85
# 1       1889.50
# 2        108.15
# ...

# %%
merged['is_male'] = merged['gender'].apply(is_male)

# %%
merged['Partner'].where(~(merged['Partner'] == 'Yes'), other = 1, inplace=True)
merged['Partner'].where(~(merged['Partner'] == 'No'), other = 0,inplace=True)

# %%
merged['Dependents'].where(~(merged['Dependents'] == 'Yes'), other = 1, inplace=True)
merged['Dependents'].where(~(merged['Dependents'] == 'No'), other = 0,inplace=True)

# %%
merged['PaperlessBilling'].where(~(merged['PaperlessBilling'] == 'Yes'), other = 1, inplace=True)
merged['PaperlessBilling'].where(~(merged['PaperlessBilling'] == 'No'), other = 0,inplace=True)

# %%
merged.head()
# Out:
#    customerID  \
# 0  7590-VHVEG
# 1  5575-GNVDE
# 2  3668-QPYBK
# 3  7795-CFOCW
# 4  9237-HQITU
#
#    BeginDate  \
# 0 2020-01-01
# 1 2017-04-01
# 2 2019-10-01
# 3 2016-05-01
# 4 2019-09-01
#
#                EndDate  \
# 0                   No
# 1                   No
# 2  2019-12-01 00:00:00
# 3                   No
# 4  2019-11-01 00:00:00
#
#              Type  \
# 0  Month-to-month
# 1        One year
# 2  Month-to-month
# 3        One year
# 4  Month-to-month
#
#   PaperlessBilling  \
# 0                1
# 1                0
# 2                1
# 3                0
# 4                1
#
#                PaymentMethod  \
# 0           Electronic check
# 1               Mailed check
# 2               Mailed check
# 3  Bank transfer (automatic)
# 4           Electronic check
#
#    MonthlyCharges  \
# 0           29.85
# 1           56.95
# 2           53.85
# 3           42.30
# 4           70.70
#
#    TotalCharges  \
# 0         29.85
# 1       1889.50
# 2        108.15
# ...

# %% [markdown]
# #### Общие и ежемесячные расходы клиентов

# %% [markdown]
# __TotalCharges__

# %%
for i, col in enumerate(['gender', 'SeniorCitizen','Partner','Dependents']): 
    plt.figure(i)
    sns.catplot(x=col, y='TotalCharges', data=merged, kind='point', color='dimgrey', aspect=2,)

# %% [markdown]
# В целом, положительный ответ в графах SeniorCitizen, Partner, Dependents влияет на общие расходы в сторону увеличения. Пол практически не влияет.

# %% [markdown]
# __MonthlyCharges__

# %%
for i, col in enumerate(['gender', 'SeniorCitizen','Partner','Dependents']): 
    plt.figure(i)
    sns.catplot(x=col, y='MonthlyCharges', data=merged, kind='point', color='dimgrey', aspect=2,)

# %% [markdown]
# У женщин, а также клиентов, не имеющих детей и имеющих партнеров, а также пенсионеров средние ежемесячные расходы выше.

# %% [markdown]
# __Gender__

# %%
plt.figure(figsize=(10,7))
plt.pie(merged.loc[merged['is_gone']==1].groupby('gender')['customerID'].count(),autopct='%1.1f%%')
plt.title('Доля мужского и женского пола у ушедших клиентов')
plt.legend(merged.loc[merged['is_gone']==1].groupby('gender')['customerID'].count().index)
plt.show()

# %% [markdown]
# Видим, что распределение пола совпадает с общим распределением. Вероятно, это незначительный фактор для модели.

# %% [markdown]
# __SeniorCitizen__

# %%
plt.figure(figsize=(10,7))
plt.pie(merged.loc[merged['is_gone']==1].groupby('SeniorCitizen')['customerID'].count(),autopct='%1.1f%%')
plt.title('Доля SeniorCitizen у ушедших клиентов')
plt.legend(merged.loc[merged['is_gone']==1].groupby('SeniorCitizen')['customerID'].count().index)
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.pie(merged.groupby('SeniorCitizen')['customerID'].count(),autopct='%1.1f%%')
plt.title('Доля SeniorCitizen у всех клиентов')
plt.legend(merged.groupby('SeniorCitizen')['customerID'].count().index)
plt.show()

# %% [markdown]
# В целом, доля SeniorCitizen у ушедших клиентов соответствует общему распределению, но несколько ниже. Видимо, возраст положительно влияет на постоянство в случае с оператором связи.

# %% [markdown]
# __Partner__

# %%
plt.figure(figsize=(10,7))
plt.pie(merged.loc[merged['is_gone']==1].groupby('Partner')['customerID'].count(),autopct='%1.1f%%')
plt.title('Доля Partner у ушедших клиентов')
plt.legend(merged.loc[merged['is_gone']==1].groupby('Partner')['customerID'].count().index)
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.pie(merged.groupby('Partner')['customerID'].count(),autopct='%1.1f%%')
plt.title('Доля Partner у всех клиентов')
plt.legend(merged.groupby('Partner')['customerID'].count().index)
plt.show()

# %% [markdown]
# Здесь разница выражена в гораздо большей степени, чем у предыдущего значения: доля более "свободных" клиентов у ушедших клиентов выше.

# %% [markdown]
# __Dependents__

# %%
plt.figure(figsize=(10,7))
plt.pie(merged.loc[merged['is_gone']==1].groupby('Dependents')['customerID'].count(),autopct='%1.1f%%')
plt.title('Доля Dependents у ушедших клиентов')
plt.legend(merged.loc[merged['is_gone']==1].groupby('Dependents')['customerID'].count().index)
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.pie(merged.groupby('Dependents')['customerID'].count(),autopct='%1.1f%%')
plt.title('Доля Dependents у всех клиентов')
plt.legend(merged.groupby('Dependents')['customerID'].count().index)
plt.show()

# %% [markdown]
# Dependents аналогично Partners.

# %% [markdown]
# __Выводы__

# %% [markdown]
# - продолжаем рассматривать данные
# - испорченных данных пока нет

# %% [markdown]
# Удалим очевидно ненужные колонки у сборного датасета:

# %%
merged = merged.drop(['gender', 'current_date', 'month_qty', 'month_came', 'year_came'], axis=1)

# %%
merged.head()
# Out:
#    customerID  \
# 0  7590-VHVEG
# 1  5575-GNVDE
# 2  3668-QPYBK
# 3  7795-CFOCW
# 4  9237-HQITU
#
#    BeginDate  \
# 0 2020-01-01
# 1 2017-04-01
# 2 2019-10-01
# 3 2016-05-01
# 4 2019-09-01
#
#                EndDate  \
# 0                   No
# 1                   No
# 2  2019-12-01 00:00:00
# 3                   No
# 4  2019-11-01 00:00:00
#
#              Type  \
# 0  Month-to-month
# 1        One year
# 2  Month-to-month
# 3        One year
# 4  Month-to-month
#
#   PaperlessBilling  \
# 0                1
# 1                0
# 2                1
# 3                0
# 4                1
#
#                PaymentMethod  \
# 0           Electronic check
# 1               Mailed check
# 2               Mailed check
# 3  Bank transfer (automatic)
# 4           Electronic check
#
#    MonthlyCharges  \
# 0           29.85
# 1           56.95
# 2           53.85
# 3           42.30
# 4           70.70
#
#    TotalCharges  \
# 0         29.85
# 1       1889.50
# 2        108.15
# ...

# %% [markdown]
# ### Информация об интернет-услугах

# %% [markdown]
# __internet.csv__ — информация об интернет-услугах

# %%
try: 
    internet = pd.read_csv('/datasets/final_provider/internet.csv')
    
except: 
    internet = pd.read_csv('datasets/final_provider/internet.csv')
    
df_info(internet)
# Out:
# (5517, 8)
#    customerID  \
# 0  7590-VHVEG
# 1  5575-GNVDE
# 2  3668-QPYBK
# 3  7795-CFOCW
# 4  9237-HQITU
#
#   InternetService  \
# 0             DSL
# 1             DSL
# 2             DSL
# 3             DSL
# 4     Fiber optic
#
#   OnlineSecurity  \
# 0             No
# 1            Yes
# 2            Yes
# 3            Yes
# 4             No
#
#   OnlineBackup  \
# 0          Yes
# 1           No
# 2          Yes
# 3           No
# 4           No
#
#   DeviceProtection  \
# 0               No
# 1              Yes
# 2               No
# 3              Yes
# 4               No
#
#   TechSupport  \
# 0          No
# 1          No
# 2          No
# 3         Yes
# 4          No
#
#   StreamingTV  \
# 0          No
# 1          No
# 2          No
# 3          No
# 4          No
#
#   StreamingMovies
# 0              No
# 1              No
# 2              No
# 3              No
# 4              No
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# ...

# %%
internet.shape[0]-internet.customerID.nunique()
# Out:
# 0

# %% [markdown]
# Дубликатов в customerID нет, но данных меньше, чем customerID в предыдущих датасетах. Очевидно, не все клиенты используют интернет. Столько клиентов интернет не использует:

# %%
merged.shape[0]-internet.shape[0]
# Out:
# 1526

# %%
internet['InternetService'].unique()
# Out:
# array(['DSL', 'Fiber optic'], dtype=object)

# %% [markdown]
# Остальные столбцы содержат только Yes / No.

# %% [markdown]
# Если рассматривать каждый из этих пунктов в разрезе ушел / не ушел, это не даст нам полезной визуально трактуемой информации. Присоединим датасет к merged, заменим Yes на 1, No на 0 для дальнейшей работы с данными, создадим возле клиента маркер, использует ли он интернет (using_internet) и перейдем к последнему датасету.

# %%
internet_customer_list = list(internet['customerID'])
def using_internet(item): 
    if item in internet_customer_list: 
        return 1
    else: 
        return 0

# %%
merged['using_internet'] = merged['customerID'].apply(using_internet)

# %%
merged = merged.merge(internet, on='customerID', how='left')

# %%
merged.shape
# Out:
# (7043, 22)

# %%
merged.head()
# Out:
#    customerID  \
# 0  7590-VHVEG
# 1  5575-GNVDE
# 2  3668-QPYBK
# 3  7795-CFOCW
# 4  9237-HQITU
#
#    BeginDate  \
# 0 2020-01-01
# 1 2017-04-01
# 2 2019-10-01
# 3 2016-05-01
# 4 2019-09-01
#
#                EndDate  \
# 0                   No
# 1                   No
# 2  2019-12-01 00:00:00
# 3                   No
# 4  2019-11-01 00:00:00
#
#              Type  \
# 0  Month-to-month
# 1        One year
# 2  Month-to-month
# 3        One year
# 4  Month-to-month
#
#   PaperlessBilling  \
# 0                1
# 1                0
# 2                1
# 3                0
# 4                1
#
#                PaymentMethod  \
# 0           Electronic check
# 1               Mailed check
# 2               Mailed check
# 3  Bank transfer (automatic)
# 4           Electronic check
#
#    MonthlyCharges  \
# 0           29.85
# 1           56.95
# 2           53.85
# 3           42.30
# 4           70.70
#
#    TotalCharges  \
# 0         29.85
# 1       1889.50
# 2        108.15
# ...

# %%
merged['OnlineSecurity'].where(~(merged['OnlineSecurity'] == 'Yes'), other = 1, inplace=True)
merged['OnlineSecurity'].where(~(merged['OnlineSecurity'] == 'No'), other = 0,inplace=True)

# %%
merged['OnlineBackup'].where(~(merged['OnlineBackup'] == 'Yes'), other = 1, inplace=True)
merged['OnlineBackup'].where(~(merged['OnlineBackup'] == 'No'), other = 0,inplace=True)

# %%
merged['DeviceProtection'].where(~(merged['DeviceProtection'] == 'Yes'), other = 1, inplace=True)
merged['DeviceProtection'].where(~(merged['DeviceProtection'] == 'No'), other = 0,inplace=True)

# %%
merged['TechSupport'].where(~(merged['TechSupport'] == 'Yes'), other = 1, inplace=True)
merged['TechSupport'].where(~(merged['TechSupport'] == 'No'), other = 0,inplace=True)

# %%
merged['StreamingTV'].where(~(merged['StreamingTV'] == 'Yes'), other = 1, inplace=True)
merged['StreamingTV'].where(~(merged['StreamingTV'] == 'No'), other = 0,inplace=True)

# %%
merged['StreamingMovies'].where(~(merged['StreamingMovies'] == 'Yes'), other = 1, inplace=True)
merged['StreamingMovies'].where(~(merged['StreamingMovies'] == 'No'), other = 0,inplace=True)

# %%
merged['InternetService'] = merged['InternetService'].fillna('Nothing')

# %%
merged['OnlineSecurity'] = merged['OnlineSecurity'].fillna(0)
merged['OnlineBackup'] = merged['OnlineBackup'].fillna(0)
merged['DeviceProtection'] = merged['DeviceProtection'].fillna(0)
merged['TechSupport'] = merged['TechSupport'].fillna(0)
merged['StreamingTV'] = merged['StreamingTV'].fillna(0)
merged['StreamingMovies'] = merged['StreamingMovies'].fillna(0)

# %% [markdown]
# __Выводы__

# %% [markdown]
# - данные без пропусков
# - переходим к последнему датасету

# %% [markdown]
# ### Информация об услугах телефонии

# %% [markdown]
# __phone.csv__ — информация об услугах телефонии

# %%
try: 
    phone = pd.read_csv('/datasets/final_provider/phone.csv')
    
except: 
    phone = pd.read_csv('datasets/final_provider/phone.csv')
    
df_info(phone)
# Out:
# (6361, 2)
#    customerID  \
# 0  5575-GNVDE
# 1  3668-QPYBK
# 2  9237-HQITU
# 3  9305-CDSKC
# 4  1452-KIOVK
#
#   MultipleLines
# 0            No
# 1            No
# 2            No
# 3           Yes
# 4           Yes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB
# None
#         customerID  \
# count         6361
# unique        6361
# top     5575-GNVDE
# freq             1
#
#        MultipleLines
# count           6361
# unique             2
# top               No
# freq            3390
# Дубликаты
# customerID       0
# MultipleLines    0
# dtype: int64
#
# Пропуски
# customerID - 0%
# MultipleLines - 0%

# %% [markdown]
# Данные о том, использует ли клиент стационарную телефонию, и в ней одну или две линии.

# %%
phone.shape[0] - phone.customerID.nunique()
# Out:
# 0

# %% [markdown]
# Дубликатов в customerID нет. Столько клиентов не использует телефон:

# %%
contract.shape[0]-phone.shape[0]
# Out:
# 682

# %% [markdown]
# Присоединим датасет к merged, заменим Yes на 1, No на 0 для дальнейшей работы с данными и создадим возле клиента маркер, использует ли он телефонию (using_phone).

# %%
merged = merged.merge(phone, how='left', on='customerID')

# %%
merged.shape
# Out:
# (7043, 23)

# %%
phone_customer_list = list(phone['customerID'])
def using_phone(item): 
    if item in phone_customer_list: 
        return 1
    else: 
        return 0

# %%
merged['using_phone'] = merged['customerID'].apply(using_phone)

# %%
merged['MultipleLines'].where(~(merged['MultipleLines'] == 'Yes'), other = 1, inplace=True)
merged['MultipleLines'].where(~(merged['MultipleLines'] == 'No'), other = 0,inplace=True)

# %%
merged['MultipleLines'] = merged['MultipleLines'].fillna(0)

# %% [markdown]
# Проверим, не забыли ли мы пропуски:

# %%
merged.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# Проверим, не появились ли у нас невзначай клиенты, которые по результатам сборки нашего датасета не пользуются ни интернетом, ни телефоном:

# %%
merged.loc[(merged['using_internet']==0) & (merged['using_phone']==0)].shape[0]
# Out:
# 0

# %% [markdown]
# __Выводы:__

# %% [markdown]
# - пропусков в данных нет, можно переходить к исследованию сборного датасета

# %% [markdown]
# ### Исследовательский анализ сборных данных

# %%
merged_before_ohe = merged.copy()

# %% [markdown]
# #### LabelEncoding

# %% [markdown]
# Заменим данные в оставшихся формально категориальных столбцах (Type, PaymentMethod):

# %%
display(merged.Type.value_counts())
display(merged.PaymentMethod.value_counts())
display(merged.InternetService.value_counts())
# Out:
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: Type, dtype: int64
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64
# Fiber optic    3096
# DSL            2421
# Nothing        1526
# Name: InternetService, dtype: int64

# %%
merged['PaymentMethod'] = LabelEncoder().fit_transform(merged['PaymentMethod'])
merged['Type'] = LabelEncoder().fit_transform(merged['Type'])
merged['InternetService'] = LabelEncoder().fit_transform(merged['InternetService'])

# %%
display(merged.Type.value_counts())
display(merged.PaymentMethod.value_counts())
display(merged.InternetService.value_counts())
# Out:
# 0    3875
# 2    1695
# 1    1473
# Name: Type, dtype: int64
# 2    2365
# 3    1612
# 0    1544
# 1    1522
# Name: PaymentMethod, dtype: int64
# 1    3096
# 0    2421
# 2    1526
# Name: InternetService, dtype: int64

# %% [markdown]
# #### Корреляция

# %%
correlation = merged.corr()

# %%
#версия scatterplot для черно-белой печати
plt.figure(figsize=(13,13))
sns.heatmap(correlation, center=0, annot=True, cmap='Greys', square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.title('Корреляция финального датасета', size=16);

# %% [markdown]
# Также посмотрим на цветную версию и pairplot.

# %%
num_corr(merged, hue='is_gone')

# %% [markdown]
# #### Проверка гипотез о влиянии факторов на целевой признак

# %% [markdown]
# Посмотрим, как влияют признаки на целевой признак с помощью chi2_contingency, определяя статистическую значимость различий ушедших и оставшихся клиентов. В перечне используемых функций у нас есть та, что группирует данные по заданному столбцу и строит таблицу с количеством ушедших и оставшихся клиентов, вычисляет статистики и выдает "решение": отвергнуть или принять нулевую гипотезу. Уровень значимости, заявленный в начале проекта, 0.05.

# %% [markdown]
# - Нулевая гипотеза: признак не связан с оттоком клиентов;
# - Альтернативная гипотеза: признак связан с оттоком клиентов.

# %%
important_features_list = []
not_important_features_list = []

# %%
categorical_columns = ['Type',
       'PaperlessBilling',
       'PaymentMethod',
       'SeniorCitizen',
       'Partner',
       'Dependents',
       'is_male',
       'using_internet',
       'InternetService',
       'OnlineSecurity',
       'OnlineBackup',
       'DeviceProtection',
       'TechSupport',
       'StreamingTV',
       'StreamingMovies',
       'MultipleLines',
       'using_phone']

for column in categorical_columns:
    table, p_chi2 = check_with_chi2(column)
    print('Колонка:', column)
    display(table)
    plt.figure(figsize=(10, 10))
    
    plt.subplot(1, 2, 1)
    plt.pie(table['is_gone'], autopct='%1.2f%%')
    plt.legend(labels=table[column], loc='best')
    plt.title('Ушедшие клиенты')
   
    
    plt.subplot(1, 2, 2)
    plt.pie(table['not_gone'], autopct='%1.2f%%')
    plt.title('Оставшиеся клиенты')
    plt.show()
    print('p-значение:', p_chi2)
    if p_chi2 < alpha:
        print('Отклонить нулевую гипотезу')
        important_features_list.append(column)
        print()
    else:
        print('Не получилось отклонить нулевую гипотезу')
        not_important_features_list.append(column)
        print()
# Out:
# Колонка: Type
#    Type  is_gone  \
# 0     0     1655
# 1     1      166
# 2     2       48
#
#    not_gone
# 0      2220
# 1      1307
# 2      1647
# p-значение: 5.863038300672725e-258
# Отклонить нулевую гипотезу
#
# Колонка: PaperlessBilling
#    PaperlessBilling  \
# 0                 0
# 1                 1
#
#    is_gone  \
# 0      469
# 1     1400
#
#    not_gone
# 0      2403
# 1      2771
# p-значение: 4.073354668665985e-58
# Отклонить нулевую гипотезу
#
# Колонка: PaymentMethod
#    PaymentMethod  \
# 0              0
# 1              1
# 2              2
# 3              3
#
#    is_gone  \
# 0      258
# 1      232
# 2     1071
# 3      308
#
#    not_gone
# 0      1286
# 1      1290
# 2      1294
# 3      1304
# p-значение: 3.6823546520097993e-140
# Отклонить нулевую гипотезу
#
# Колонка: SeniorCitizen
#    SeniorCitizen  \
# 0              0
# 1              1
#
#    is_gone  \
# 0     1393
# 1      476
#
#    not_gone
# 0      4508
# 1       666
# ...

# %%
print('Важные признаки:')
print(*important_features_list, sep=', ')
print()
print('Неважные признаки:')
print(*not_important_features_list, sep=', ')
# Out:
# Важные признаки:
# Type, PaperlessBilling, PaymentMethod, SeniorCitizen, Partner, Dependents, using_internet, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, MultipleLines
#
# Неважные признаки:
# is_male, using_phone

# %% [markdown]
# __Выводы:__

# %% [markdown]
# Видим, что не получилось отклонить нулевую гипотезу только по признаку пола и using_phone. Поэтому мы удалим их из датафрейма, также, как и TotalCharges.

# %%
merged = merged.drop(['is_male', 'using_phone', 'TotalCharges'], axis=1)

# %% [markdown]
# Остальные признаки пока оставим несмотря на то, что есть корреляция между Type и lifetime_days, а также StreamingMovies, TV с MonthlyCharges. Посмотрим, как покажут себя модели.

# %% [markdown]
# #### Удаление ненужных признаков для ML

# %% [markdown]
# Финальный датасет для машинного обучения такж не будет содержать дат и customerID:

# %%
merged_before_ohe = merged_before_ohe.drop(['customerID', 'BeginDate', 'EndDate', 'TotalCharges'], axis=1)

# %%
merged_ohe = pd.get_dummies(merged_before_ohe, drop_first=True)

# %% [markdown]
# #### Выводы

# %% [markdown]
# - провели этап исследования и подготовки данных для моделей машинного обучения,
# - обозначили target,
# - добавили новые features,
# - изучили и удалили корреляции,
# - подготовили сводный датасет, закодировали категориальные переменные,
# - далее проясним вопросы с тим-лидом и перейдем к машинному обучению

# %% [markdown]
# ## План работы, направленный тим-лиду:

# %% [markdown]
# 1. Задать появившиеся вопросы по данным тим-лиду, возможно, скорректировать фиеальный датасет в соответствии с полученными ответами.
# 2. Разделить датасет на features и target.
# 3. Подобрать гиперпараметры и обучить модели классификации: LogisticRegression, RandomForestClassifier, LGBMClassifier. Предварительно оценить их на валидационной выборке (или с помощью кросс-валидации).
# 4. Оценить эффективности моделей на тестовой выборке.
# 5. Построить финальную табличку, графики метрик и сделать выводы

# %% [markdown]
# ## Список уточняющих вопросов для тим-лида

# %% [markdown]
# - верно ли предположение о содержании данных: TotalCharges, SeniorCitizen, Dependents и др.?
# - есть данные о старых клиентах, но нет данных об уходе клиентов до 2019 г.? есть данные, что клиенты уходили с января и в конце года, а в середине года? клиенты вообще не уходили до 2019 г.? данные корректные?
# - как формируется "решение" о том, что клиент "ушел"? он перестал платить / тратить / расторг договор?
# - какую метрику мы будем использовать для оценки моделей? мы знаем, какую метрику максимизируем, или мы это решаем сами? (предлагаю ROC-AUC + Accuracy, чтобы предотвратить потерю клиентов, но и не раздавать промокоды и скидки тем, кто не собирается уходить)
# - верно ли предположение, что при выборе модели скорость ее обучения / предсказания будет иметь значение, но не будет основным критерием выбора, т.к. модель не планируется использовать в режиме он-лайн, а для обработки клиентской базы с целью рассылки материалов (скидок, промокодов и т.д.), т.е. метрики модели будут на первом месте при ее оценке?

# %% [markdown]
# ## Построение моделей машинного обучения

# %% [markdown]
# Построим, подберем гиперпараметры и обучим следующие ML-модели:
# - LogisticRegression,
# - RandomForestClassifier,
# - LGBMClassifier

# %% [markdown]
# Посмотрим итоговый датасет:

# %%
merged_ohe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   MonthlyCharges                         7043 non-null   float64
#  1   lifetime_days                          7043 non-null   int64
#  2   is_gone                                7043 non-null   int64
#  3   SeniorCitizen                          7043 non-null   int64
#  4   is_male                                7043 non-null   int64
#  5   using_internet                         7043 non-null   int64
#  6   OnlineSecurity                         7043 non-null   int64
#  7   OnlineBackup                           7043 non-null   int64
#  8   DeviceProtection                       7043 non-null   int64
#  9   TechSupport                            7043 non-null   int64
#  10  StreamingTV                            7043 non-null   int64
# ...

# %%
target = merged_ohe['is_gone']
features = merged_ohe.drop(['is_gone'], axis=1)

# %%
features_train, features_test, target_train, target_test = train_test_split(features, target,
                                                                              test_size = 0.2,
                                                                              random_state = current_state,
                                                                              stratify = target,
                                                                              shuffle = True)

# %%
print(f"Количество строк в y_train по классам: {np.bincount(target_train)}")
print(f"Количество строк в y_test по классам: {np.bincount(target_test)}")
# Out:
# Количество строк в y_train по классам: [4139 1495]
# Количество строк в y_test по классам: [1035  374]

# %% [markdown]
# Есть дисбаланс классов (тех, кто ушел, меньше, чем тех, кто остался) - это мы выяснили и на этапе исследования. Вероятнее всего, это повлияет на качество моделей.

# %% [markdown]
# Масштабируем числовые признаки с помощью StandardScaler:

# %%
numeric_columns = ['MonthlyCharges', 'lifetime_days']
our_ohe_scaler = StandardScaler()
our_ohe_scaler.fit(features_train[numeric_columns])
# Out:
# StandardScaler()

# %%
features_train[numeric_columns] = our_ohe_scaler.transform(features_train[numeric_columns])
features_test[numeric_columns] = our_ohe_scaler.transform(features_test[numeric_columns])

# %%
features_train.head()
# Out:
#       MonthlyCharges  \
# 4760        0.338121
# 4031        1.514596
# 6809        0.333129
# 6063       -1.522274
# 686        -1.342558
#
#       lifetime_days  \
# 4760       1.368541
# 4031       1.610287
# 6809      -1.151751
# 6063       1.531486
# 686        0.758169
#
#       SeniorCitizen  \
# 4760              0
# 4031              0
# 6809              1
# 6063              0
# 686               0
#
#       is_male  \
# 4760        1
# 4031        0
# 6809        1
# 6063        0
# 686         1
#
#       using_internet  \
# 4760               1
# 4031               1
# 6809               1
# 6063               0
# 686                0
#
#       OnlineSecurity  \
# 4760               1
# 4031               0
# 6809               0
# 6063               0
# 686                0
#
#       OnlineBackup  \
# 4760             1
# 4031             1
# 6809             0
# 6063             0
# 686              0
#
#       DeviceProtection  \
# 4760                 1
# ...

# %% [markdown]
# __Dummy__

# %% [markdown]
# Первой моделью сделаем dummy-модель.

# %%
dummy_clsf = DummyClassifier(
    strategy="most_frequent", 
    random_state=current_state
)

dummy_clsf.fit(features_train, target_train)

display(dummy_clsf.score(features_train, target_train))
display(dummy_clsf.score(features_test, target_test))
# Out:
# 0.7346467873624423
# 0.7345635202271115

# %%
roc_auc_score(target_test, dummy_clsf.predict(features_test))
# Out:
# 0.5

# %% [markdown]
# На графике кривых график этой модели будет прямая из нижнего левого угла в правый верхний.

# %% [markdown]
# ### LogisticRegression

# %%
model_name='LogisticRegression'

# %%
model_log_reg = LogisticRegression(solver = 'liblinear')
penalty = ['l1', 'l2']
#C = np.logspace(-4, 4, 50)
class_weight = [None, 'balanced']

# %%
hyperparameters = dict(
    #C=C, 
    penalty=penalty, 
    class_weight=class_weight
)

# %%
best_lr = GridSearchCV(model_log_reg, 
                                hyperparameters, 
                                cv = 5,
                                #n_iter = 10,
                                #random_state = current_state,
                                #verbose = 0, 
                                n_jobs = -1, 
                                scoring = 'roc_auc')

# %%
model_log_reg = LogisticRegression(solver = 'liblinear', penalty='l1', class_weight='balanced')

# %%
train_time_lr, predict_time_lr, roc_auc_lr, accuracy_lr, precision_lr, recall_lr = model_final(
    best_lr,
    features_train,
    target_train,
    features_test,
    target_test)

# %% [markdown]
# Выведем получившееся для справки:

# %%
display(train_time_lr, predict_time_lr, roc_auc_lr, accuracy_lr, precision_lr, recall_lr)
# Out:
# 5.045293807983398
# 0.002995729446411133
# 0.8496770776821927
# 0.7466288147622427
# 0.5148861646234676
# 0.786096256684492

# %%
results_upd(0, model_name, train_time_lr, predict_time_lr, roc_auc_lr, accuracy_lr)
# Out:
#            model_name  \
# 0  LogisticRegression
#
#   time_learn  \
# 0   5.045294
#
#   time_predict  \
# 0     0.002996
#
#   ROC_AUC_test  \
# 0     0.849677
#
#   accuracy_test
# 0      0.746629

# %% [markdown]
# ### RandomForestClassifier

# %%
model_name='RandomForestClassifier'

# %%
model_rfc = RandomForestClassifier()

# %%
n_estimators = [int(x) for x in np.linspace(start = 5, stop = 50, num = 10)]
max_features = ['log2', 'sqrt']
max_depth = [int(x) for x in np.linspace(start = 1, stop = 15, num = 15)]
min_samples_split = [int(x) for x in np.linspace(start = 2, stop = 50, num = 10)]
min_samples_leaf = [int(x) for x in np.linspace(start = 1, stop = 50, num = 10)]
criterion = ['gini', 'entropy']
class_weight = [None, 'balanced']

param_dict = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'criterion': criterion}

# %%
best_forest = RandomizedSearchCV(model_rfc,
                               param_dict,
                               cv = 5,
                               n_iter = 10,
                               random_state = 0,
                               verbose = 0, 
                               n_jobs= 1, 
                               scoring = 'roc_auc')

# %%
train_time_rfc, predict_time_rfc, roc_auc_rfc, accuracy_rfc, precision_rfc, recall_rfc = model_final(
    best_forest, features_train, target_train, features_test, target_test)

# %%
display(train_time_rfc, predict_time_rfc, roc_auc_rfc, accuracy_rfc, precision_rfc, recall_rfc)
# Out:
# 6.466336727142334
# 0.0031719207763671875
# 0.8585341910150094
# 0.8183108587650816
# 0.736
# 0.4919786096256685

# %%
results_upd(1, model_name, train_time_rfc, predict_time_rfc, roc_auc_rfc, accuracy_rfc)
# Out:
#                model_name  \
# 0      LogisticRegression
# 1  RandomForestClassifier
#
#   time_learn  \
# 0   5.045294
# 1   6.466337
#
#   time_predict  \
# 0     0.002996
# 1     0.003172
#
#   ROC_AUC_test  \
# 0     0.849677
# 1     0.858534
#
#   accuracy_test
# 0      0.746629
# 1      0.818311

# %% [markdown]
# RandomForestClassifier показывает чуть лучшие результаты, но требуется более высокое значение метрики.

# %% [markdown]
# ### LGBMClassifier

# %%
model_name='LGBMClassifier'

# %%
categories = ['Type', 
              'PaperlessBilling', 
              'PaymentMethod', 
              'SeniorCitizen', 
              'Partner', 
              'Dependents', 
              'is_male', 
              'using_internet', 
              'InternetService', 
              'OnlineSecurity', 
              'OnlineBackup', 
              'DeviceProtection', 
              'TechSupport', 
              'StreamingTV', 
              'StreamingMovies', 
              'MultipleLines', 
              'using_phone']
for column in categories:
    merged_before_ohe[column] = merged_before_ohe[column].astype('category')

# %%
target_boost = merged_before_ohe['is_gone']
features_boost = merged_before_ohe.drop(['is_gone'], axis=1)

# %%
features_train_boost, features_test_boost, target_train_boost, target_test_boost = train_test_split(
    features_boost, target_boost, test_size=0.2, random_state = current_state,shuffle=True,stratify=target_boost)

# %%
scaler_boost = StandardScaler()
scaler_boost.fit(features_train_boost[numeric_columns])
features_train_boost[numeric_columns] = scaler_boost.transform(features_train_boost[numeric_columns])
features_test_boost[numeric_columns] = scaler_boost.transform(features_test_boost[numeric_columns])

# %%
model_lgbmc = LGBMClassifier(objective='binary', metric='auc')

# %%
search_space = [{'learning_rate': [0.0005, 0.001, 0.01, 0.05, 0.1], 
                      'n_estimators': [100, 200, 300, 500],
                      'num_leaves': [10, 20, 30, 50, 70, 100, 150],
                      'class_weight': [None, 'balanced']}]

# %%
rs_lgbmc = RandomizedSearchCV(model_lgbmc, 
                        search_space, 
                        cv = 5, 
                        n_iter=5,
                        random_state=current_state,
                        verbose = 0, 
                        n_jobs=1,
                        scoring={'AUC':'roc_auc'},
                        refit='AUC')

# %%
train_time_lgbmc, predict_time_lgbmc, roc_auc_lgbmc, accuracy_lgbmc, precision_lgbmc, recall_lgbmc = model_final(
    rs_lgbmc, 
    features_train_boost, 
    target_train_boost, 
    features_test_boost, 
    target_test_boost
)

# %%
display(train_time_lgbmc, predict_time_lgbmc, roc_auc_lgbmc, accuracy_lgbmc, precision_lgbmc, recall_lgbmc)
# Out:
# 14.469363451004028
# 0.046874046325683594
# 0.9035276033997259
# 0.8559261887863733
# 0.7958477508650519
# 0.6149732620320856

# %%
results_upd(2, model_name, train_time_lgbmc, predict_time_lgbmc, roc_auc_lgbmc, accuracy_lgbmc)
# Out:
#                model_name  \
# 0      LogisticRegression
# 1  RandomForestClassifier
# 2          LGBMClassifier
#
#   time_learn  \
# 0   5.045294
# 1   6.466337
# 2  14.469363
#
#   time_predict  \
# 0     0.002996
# 1     0.003172
# 2     0.046874
#
#   ROC_AUC_test  \
# 0     0.849677
# 1     0.858534
# 2     0.903528
#
#   accuracy_test
# 0      0.746629
# 1      0.818311
# 2      0.855926

# %% [markdown]
# Модель достигает целевого значения метрики, хоть и имеет более долгий срок обучения. Мы не планируем использовать модель в режиме он-лайн, и т.к. ее цель - для внутреннего использования определить перечень клиентов, которых компания рискует потерять, и начать в их отношении действия по удержанию, то время обучения недостатком мы считать не будем.

# %% [markdown]
# ## Оценка метрик моделей

# %% [markdown]
# ### ROC-AUC кривая

# %%
fpr1, tpr1, thresholds1 = roc_curve(target_test, best_lr.predict_proba(features_test)[:,1], pos_label=1)
fpr2, tpr2, thresholds2 = roc_curve(target_test, best_forest.predict_proba(features_test)[:,1], pos_label=1)
fpr3, tpr3, thresholds3 = roc_curve(target_test_boost, rs_lgbmc.predict_proba(features_test_boost)[:,1],
                                                                                           pos_label=1)

auc_regress = roc_auc_score(target_test, best_lr.predict_proba(features_test)[:,1])
auc_forest = roc_auc_score(target_test, best_forest.predict_proba(features_test)[:,1])
auc_lgbm = roc_auc_score(target_test_boost, rs_lgbmc.predict_proba(features_test_boost)[:,1])

lw=2
fig, ax = plt.subplots(figsize=(10,8))
ax.plot(fpr1, tpr1, lw=lw, label= 'LogisticRegression, AUC-ROC = %.2f' %roc_auc_lr)
ax.plot(fpr2, tpr2, lw=lw, label= 'RandomForestClassifier, AUC-ROC = %.2f' %roc_auc_rfc)
ax.plot(fpr3, tpr3, lw=lw, label= 'LGBMClassifier, AUC-ROC = %.2f' %roc_auc_lgbmc)

plt.title('ROC-кривые', fontsize=16)
plt.legend(loc='lower right')
plt.plot([0,1], [0,1])
plt.xlim([0.0, 1.0])
plt.xlabel('FPR', fontsize=16)
plt.ylabel('TPR', fontsize=16)
plt.ylim([0.0, 1.05])
plt.tick_params(which='major', labelsize=14)
plt.show()

# %% [markdown]
# Для того, чтобы сделать выводы, посмотрим также на матрицу ошибок.

# %% [markdown]
# ### Матрица ошибок

# %%
cm_lr = pd.DataFrame(confusion_matrix(target_test, best_lr.predict(features_test)))
cm_forest = pd.DataFrame(confusion_matrix(target_test, best_forest.predict(features_test)))
cm_lgbmc = pd.DataFrame(confusion_matrix(target_test_boost, rs_lgbmc.predict(features_test_boost)))

cm_list = [cm_lr, cm_forest, cm_lgbmc]
cm_data = ['LogisticRegression', 'RandomForestClassifier', 'LGBMClassifier']
sns.set(font_scale=1)

for cm, cm_name in zip(cm_list, cm_data):
    sns.heatmap(cm, annot=True, cmap='YlGnBu', fmt='d', annot_kws={'fontsize':12})
    plt.title('Матрица ошибок - ' + cm_name, fontsize=14)
    plt.xlabel('Предсказания', fontsize=12)
    plt.ylabel('Ответы', fontsize=12)
    plt.show()
print()

# %% [markdown]
# __Вывод__

# %% [markdown]
# LGBMClassifier имеет метрику ROC-AUC, которая нас устраивает, а также показыват самые высокие другие метрики: точности, полноты. Это означает, что модель точнее других, обученных и проверенных нами, предсказывает тех клиентов, которые уйдут, и - соглансо матрице ошибок - не завышает False Negative, т.к. упускает меньше клиентов, которые на самом деле уходят, и не завышает False Positive.

# %% [markdown]
# Это означает, что если мы будем принимать решение об инструментах удержания клиентов, которых мы пометим как находящихся в зоне риска, мы не станем впустую тратить деньги (в виде, например, скидок или промокодов), а адресуем их в большей степени тем клиентам, с которыми это будет иметь положительный результат.

# %% [markdown]
# Что касается размера скидки / промокода, то для того, чтобы давать рекомендации об этом, у нас недостаточно данных, т.к. мы не знаем себестоимости услуг (создание сети и обслуживания кабеля и т.д.)

# %% [markdown]
# ### Важность признаков

# %% [markdown]
# И напоследок взглянем на важность признаков в выбранной нами модели.

# %%
best_lgbmc = rs_lgbmc.best_estimator_

# %%
feat_importances = pd.Series(best_lgbmc.feature_importances_, index=features_test_boost.columns)

plt.figure(figsize=(8,5))
feat_importances.nlargest(20).plot(kind='barh', color='gray')

plt.title('Важность признаков', size=18, y=1.02);

# %% [markdown]
# ### Альтернативная модель LGBMClassifier на части данных

# %% [markdown]
# Протестируем предположение о том, что даже на основании всего лишь двух основных признаков - MonthlyCharges и lifetime_days можно построить модель, которая будет не хуже (или не сильно хуже) предсказывать уход клиентов. Если это так, то это может сэкономить нам время и силы на сбор остальных данных о клиенте. Используем LGBMClassifier.

# %%
model_name = 'Experimental LGBMClassifier'

# %%
df_cut = merged_before_ohe[['lifetime_days', 'MonthlyCharges', 'is_gone']]
df_cut.head()
# Out:
#    lifetime_days  \
# 0             31
# 1           1036
# 2             61
# 3           1371
# 4             61
#
#    MonthlyCharges  \
# 0           29.85
# 1           56.95
# 2           53.85
# 3           42.30
# 4           70.70
#
#    is_gone
# 0        0
# 1        0
# 2        1
# 3        0
# 4        1

# %%
df_cut.corr()
# Out:
#                 lifetime_days  \
# lifetime_days        1.000000
# MonthlyCharges       0.247754
# is_gone             -0.352673
#
#                 MonthlyCharges  \
# lifetime_days         0.247754
# MonthlyCharges        1.000000
# is_gone               0.193356
#
#                  is_gone
# lifetime_days  -0.352673
# MonthlyCharges  0.193356
# is_gone         1.000000

# %%
target_boost_exp = df_cut['is_gone']
features_boost_exp = df_cut.drop(['is_gone'], axis=1)

# %%
features_train_boost_exp, features_test_boost_exp, target_train_boost_exp, target_test_boost_exp = train_test_split(
    features_boost_exp, target_boost_exp, test_size=0.2, random_state = current_state, shuffle=True, stratify=target_boost)

# %%
cut_scaler = StandardScaler()
cut_scaler.fit(features_train_boost_exp)
features_train_boost_exp = cut_scaler.transform(features_train_boost_exp)
features_test_boost_exp = cut_scaler.transform(features_test_boost_exp)

# %%
exp_lgbmc = LGBMClassifier(objective='binary', metric='auc')

search_space = [{'learning_rate': [0.0005, 0.001, 0.01, 0.05, 0.1], 
                      'n_estimators': [100, 200, 300, 500],
                      'num_leaves': [10, 20, 30, 50, 70, 100, 150],
                      'class_weight': [None, 'balanced']}]

rs_exp_lgbmc = RandomizedSearchCV(model_lgbmc, 
                        search_space, 
                        cv = 5, 
                        n_iter=5,
                        random_state=current_state,
                        verbose = 0, 
                        n_jobs=1,
                        scoring={'AUC':'roc_auc'},
                        refit='AUC')

train_time_exp_lgbmc, predict_time_exp_lgbmc, roc_auc_exp_lgbmc, accuracy_exp_lgbmc, precision_exp_lgbmc, recall_exp_lgbmc = model_final(
    rs_exp_lgbmc, 
    features_train_boost_exp, 
    target_train_boost_exp, 
    features_test_boost_exp, 
    target_test_boost_exp
)

display(train_time_exp_lgbmc, predict_time_exp_lgbmc, roc_auc_exp_lgbmc, accuracy_exp_lgbmc, precision_exp_lgbmc, recall_exp_lgbmc)
# Out:
# 10.328113079071045
# 0.031250715255737305
# 0.9132126895554006
# 0.872249822569198
# 0.8233333333333334
# 0.660427807486631

# %%
results_upd(3, model_name, train_time_exp_lgbmc, predict_time_exp_lgbmc, roc_auc_exp_lgbmc, accuracy_exp_lgbmc)
# Out:
#                     model_name  \
# 0           LogisticRegression
# 1       RandomForestClassifier
# 2               LGBMClassifier
# 3  Experimental LGBMClassifier
#
#   time_learn  \
# 0   5.045294
# 1   6.466337
# 2  14.469363
# 3  10.328113
#
#   time_predict  \
# 0     0.002996
# 1     0.003172
# 2     0.046874
# 3     0.031251
#
#   ROC_AUC_test  \
# 0     0.849677
# 1     0.858534
# 2     0.903528
# 3     0.913213
#
#   accuracy_test
# 0      0.746629
# 1      0.818311
# 2      0.855926
# 3       0.87225

# %% [markdown]
# Как видим, эта модель показывает еще лучшие результаты, чем предыдущая версия LGBMClassifier, и имеет гораздо меньшее время обучения, так что можно вообще взять только эти два признака, и использовать данную версию модели в настоящий момент.

# %% [markdown]
# В дальнейшем, когда мы будем использовать меры по удержанию клиентов, ситуация изменится. Какая-то часть клиентов, тем не менее, все равно будет уходить, и причины их ухода, как и признаки, описывающие эти причины, скорее всего, станут иными, поэтому потребуется новый анализ и новая модель.

# %% [markdown]
# __Финальная версия модели__

# %% [markdown]
# - данные для модели: MonthlyCharges, lifetime_days
# - LGBMClassifier:

# %%
rs_exp_lgbmc.best_params_
# Out:
# {'num_leaves': 70,
#  'n_estimators': 500,
#  'learning_rate': 0.05,
#  'class_weight': None}

# %% [markdown]
# __Время исполнения тетради с проектом__

# %%
project_end_time = time.time() - project_start_time
round(project_end_time, 2)
# Out:
# 154.68

# %% [markdown]
# ## Отчет по проекту

# %% [markdown]
# В отчёте ответим на вопросы:
# - Какие пункты плана были выполнены, а какие — нет (поясните почему)?
# - Какие трудности возникли и как вы их преодолели?
# - Какие ключевые шаги в решении задачи выделили?
# - Какая ваша итоговая модель и какое у неё качество?

# %% [markdown]
# __Какие пункты плана были выполнены, а какие — нет (поясните почему)?__

# %% [markdown]
# Пунктами плана были следующие:
# 1. Задать появившиеся вопросы по данным тим-лиду, возможно, скорректировать фиеальный датасет в соответствии с полученными ответами - _выполнено_
# 2. Разделить датасет на features и target - _выполнено_
# 3. Подобрать гиперпараметры и обучить модели классификации: LogisticRegression, RandomForestClassifier, LGBMClassifier. Предварительно оценить их на валидационной выборке (или с помощью кросс-валидации) - _выполнено_
# 3. Оценить эффективности моделей на тестовой выборке - _выполнено_
# 4. Построить финальную табличку, графики метрик и сделать выводы - _выполнено_

# %% [markdown]
# __Какие трудности возникли и как вы их преодолели?__

# %% [markdown]
# - К началу работы я хуже всего понимала LGBMClassifier, хотя предполагала, что именно он и достигнет целевой метрики для нашей задали. Его изучение потребовало дополнительного времени и чтения материалов (в основном, документации), а также практических попыток, многих - неуспешных :-)
# - Также, хотя я работаю в продажах (новые автомобили, спецтехника и т.д.) более 16 лет, для меня гораздо более сложным, чем, например, предсказание температуры плавления стали, остается анализ бизнес-кейсов, т.к. нет никакого описанного (как в технической документрации в случае с технической / технологической задачей) "рецепта успеха" для продаж / бизнеса, т.к. ситуация постоянно меняется, и многие факторы, которые влияют на продажи и поведение клиентов, никак не выразить математически, и в ситуации, когда рынок меняется беспрецедентно, нет даже эксперта, который может дать совет по бизнес-решениям на основании опыта (опыта такого нет) - в общем, трудность в том, чтобы предсказать и учесть "черного лебедя" - если не на этапе создания модели, то хотя бы на этапе ее трактовки.
# - Также сейчас для меня открытым вопросом является тема когнитивных искажений при сборе и анализе информации, эту тему я изучаю дополнительно. И если здесь мы получили некий готовый сет данных + возможность задать тим-лиду вопросы по данным, но не получили никакой возможности дополнительно собрать данные, расширить их, то этот вопрос здесь не очень актуален: других данных все равно нет. Но сейчас я делаю практический проект на своей текущей работе (хотя еще не являюсь аналитиком по профессии и должности), и эта тема важна как никогда. Потому что я сама поставила запрос к данным (как бизнес, т.к. конкретно у нашего бизнеса сейчас такого запроса нет), сама разбираюсь, какие данные мне помогут ответить на эти вопросы, сама собираю эти данные (из 1С, в основном), сама делаю выводы и рекомендации по этим данным. И сложность для меня в том, что с одной стороны, я 16 лет знаю этот бизнес, и понимаю, какие метрики здесь важны, и о чем они нам говорят, а с другой стороны - а правда ли это так на самом деле, или я приношу некое свое мнение / стереотип и пытаюсь при помощи данных его подтвердить, собираю ли я все данные на самом деле, или есть те данные, которые я не собираю, но они говорят о противоположном, и не является ли факт отсутствия данных о чем-либо, уже говорящим о том, что в этом месте есть упущение для бизнеса.
# - Также вопрос качества данных (пропусков, миллиона разномастных датасетов) - чего не было конкретно в этом проекте, но что, опять же, обычно проблема - на том уровне оперирования данными, который есть у компаний, не являющихся (я верю, что только пока :-) ) приверженцами data-driven решений.
# - Также я хотела сделать Tableau-дашборд к данному проекту, но столкнулась с трудностями в регистрации нового аккаунта из-за проблем с серверами public.tablea (возможно, позже они пропадут, сейчас есть)

# %% [markdown]
# __Какие ключевые шаги в решении задачи выделили?__

# %% [markdown]
# 1. Понимание бизнес-целей, и после этого - технических задач исследования, а также метрик, которые мы будем использовать для понимания того, успешна модель или нет
# 2. Знакомство с данными, понимание, что содержится в данных, сможем ли при помощи этих данных дать ответы на те вопросы, которые перед нами поставлены
# 3. Понимание качества данных, работа с типами данных, пропусками, выбросами. Понимание того, что будет target, какой параметр - как его получить из данных: по какому показателю (совокупности показателей) мы поймем, что клиент принадлежит к этому классу (для целей нашей классификации)
# 4. Исследование данных - описательные статистики + визуализация данных, выдвижение на основе этого предположений и гипотез
# 5. Проверка гипотез и предположений (в т.ч. о том, какие features влияют на результат)
# 6. Отбор features, создание дополнительных features (если требуется)
# 7. Подготовка данных для машинного обучения
# 8. Выбор, создание, обучение моделей машинного обучения
# 9. Тестирование моделей, сведение результатов (метрик) в таблицу, графическая иллюстрация метрик, исследование остатков (если есть)
# 10. Выводы по метрикам (в бизнес-формулировках) и определение финальной модели

# %% [markdown]
# __Какая ваша итоговая модель и какое у неё качество?__

# %% [markdown]
# LGBMClassifier {'num_leaves': 70,  'n_estimators': 500, 'learning_rate': 0.05, 'class_weight': None}:
# - ROC-AUC: 0.9132
# - ACCURACY: 0.8722
# - PRECISION: 0.8233
# - RECALL: 0.6604
